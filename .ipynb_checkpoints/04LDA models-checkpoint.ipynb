# %% [markdown]
# https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/

# %%
import pandas as pd
from pandas import DataFrame, concat
import numpy as np
df_update = pd.read_csv('df_update.csv', index_col=[0])
skill_cell = pd.read_csv('skill_cell.csv',header=None)

# %%
skill_cell.columns=['skill_list']
skill_cell.head()
# Out:
#                                                                  skill_list
# 0  Python,SQL,R,Spark,Hive,AWS,Data-Warehouse,Business-Intelligence,Network
# 1                                                       SQL,R,Excel,Network
# 2                                                                   R,Excel
# 3                                        R,Microsoft-Office,Excel,Marketing
# 4                                                                         R

# %%
list_of_skill = skill_cell['skill_list'].to_list()

# %%
list_of_skill[:3]
# Out:
# ['Python,SQL,R,Spark,Hive,AWS,Data-Warehouse,Business-Intelligence,Network',
#  'SQL,R,Excel,Network',
#  'R,Excel']

# %%
from nltk.tokenize import word_tokenize
example = list_of_skill
tokenized_sents = [word_tokenize(i) for i in example]

# %%
tokenized_sents
# Out:
# [['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Spark',
#   ',',
#   'Hive',
#   ',',
#   'AWS',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Network'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Network'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Marketing'],
#  ['R'],
#  ['R'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'AWS',
#   ',',
#   'Data-Analysis',
#   ',',
#   'PostgreSQL',
#   ',',
#   'MySQL',
#   ',',
#   'S3',
#   ',',
#   'SaaS',
#   ',',
#   'SSH',
#   ',',
#   'Tomcat'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Go'],
#  ['R'],
#  ['SQL', ',', 'R', ',', 'Marketing', ',', 'CSS', ',', 'WordPress'],
#  ['Software-Development', ',', '.Net', ',', 'C', '#', ',', 'SharePoint'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Linux',
#   ',',
#   'Go',
#   ',',
#   'CSS',
#   ',',
#   'GIS',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Omniture',
#   ',',
#   'Workday'],
#  ['R'],
#  ['SQL', ',', 'R'],
#  ['Python', ',', 'R', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'MATLAB', ',', 'Data-Science', ',', 'Go'],
#  ['SQL', ',', 'R', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Spark', ',', 'SDLC'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Accounting'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Hive',
#   ',',
#   'Excel',
#   ',',
#   'Workday'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'Tableau', ',', 'Scala', ',', 'Marketing'],
#  ['R', ',', 'Excel', ',', 'SPSS', ',', 'Marketing', ',', 'Go'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'Go'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Marketing'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Microsoft-Word',
#   ',',
#   'Operations-Research'],
#  ['SQL', ',', 'R', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Go', ',', 'Google-Analytics'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'CI',
#   ',',
#   'Go',
#   ',',
#   'NIST'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'AI',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'IDS'],
#  ['R', ',', 'Excel', ',', 'Network'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'SAS', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Visio', ',', 'CI', ',', 'SharePoint'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'UI'],
#  ['SQL', ',', 'R'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau'],
#  ['R', ',', 'Excel', ',', 'Quality-Management'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Tableau',
#   ',',
#   'Google-Cloud-Platform',
#   ',',
#   'Go',
#   ',',
#   'Accounting'],
#  ['Python', ',', 'R', ',', 'Go'],
#  ['R', ',', 'Network', ',', 'UI'],
#  ['R', ',', 'Excel', ',', 'Perl', ',', 'Epic'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Marketing',
#   ',',
#   'SaaS',
#   ',',
#   'Marketo'],
#  ['R', ',', 'Excel', ',', 'Accounting', ',', 'Audits'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'XML',
#   ',',
#   'Visio',
#   ',',
#   'Go',
#   ',',
#   'Application-Support'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'Excel'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Perl',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Data-Management',
#   ',',
#   'Epic',
#   ',',
#   'Managed-Care'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Go',
#   ',',
#   'iOS',
#   ',',
#   'Android'],
#  ['R'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Hadoop',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Go'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Scala', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Biostatistics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Linux',
#   ',',
#   'Excel',
#   ',',
#   'CI',
#   ',',
#   'Accounting'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Biostatistics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Hadoop',
#   ',',
#   'Tableau',
#   ',',
#   'Hive',
#   ',',
#   'SAS',
#   ',',
#   'Big-Data',
#   ',',
#   'Linux',
#   ',',
#   'Marketing',
#   ',',
#   'Digital-Marketing'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Machine-Learning',
#   ',',
#   'R',
#   ',',
#   'Spark',
#   ',',
#   'SAS',
#   ',',
#   'Scala',
#   ',',
#   'MATLAB',
#   ',',
#   'Data-Science',
#   ',',
#   'STATA'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Go', ',', 'Google-Analytics'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'SAS', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Go'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'AWS',
#   ',',
#   'Data-Science',
#   ',',
#   'S3',
#   ',',
#   'GIS',
#   ',',
#   'PostGIS'],
#  ['Data-Analysis', ',', 'Excel', ',', 'Business-Intelligence'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Marketing'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Go'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'Go'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Jira',
#   ',',
#   'iOS'],
#  ['Python', ',', 'R', ',', 'Git', ',', 'C', '#', ',', 'Quantitative-Research'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Quality-Management',
#   ',',
#   'Managed-Care'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Hadoop',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'AWS',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Informatica',
#   ',',
#   'Data-Management',
#   ',',
#   'Apache',
#   ',',
#   'SAP',
#   ',',
#   'Predictive-Analytics',
#   ',',
#   'OBIEE'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'SAS', ',', 'Scripting', ',', 'SPSS'],
#  ['Python', ',', 'R', ',', 'Tableau', ',', 'Informatica'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'SaaS'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-SQL-Server',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'C',
#   '#',
#   ',',
#   'PowerShell',
#   ',',
#   'Accounting'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'Go',
#   ',',
#   'Clojure'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'SAS', ',', 'Data-Science'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Salesforce-CRM'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Marketing',
#   ',',
#   'Business-Management'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Spark',
#   ',',
#   'Big-Data',
#   ',',
#   'AWS',
#   ',',
#   'Data-Science',
#   ',',
#   'Go',
#   ',',
#   'iOS',
#   ',',
#   'Android'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Oracle', ',', 'Excel', ',', 'SDLC'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Visio',
#   ',',
#   'SEO'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'JavaScript',
#   ',',
#   'Marketing',
#   ',',
#   'SAP',
#   ',',
#   'Digital-Marketing'],
#  ['SQL', ',', 'R', ',', 'Business-Intelligence'],
#  ['R', ',', 'Excel', ',', 'Business-Management'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'AI', ',', 'Excel', ',', 'SAP'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Marketing'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Marketing',
#   ',',
#   'Business-Management'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['R', ',', 'Marketing', ',', 'SharePoint'],
#  ['R', ',', 'Tableau', ',', 'Go'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'SAP',
#   ',',
#   'Go',
#   ',',
#   'React',
#   ',',
#   'Epic',
#   ',',
#   'PeopleSoft'],
#  ['R', ',', 'Project-Management'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'CI',
#   ',',
#   'Go',
#   ',',
#   'NIST'],
#  ['R', ',', 'SAS', ',', 'Excel', ',', 'Marketing'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Microsoft-Word',
#   ',',
#   'Accounting',
#   ',',
#   'Managed-Care'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'UI'],
#  ['R'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence'],
#  ['R'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Medical-Insurance',
#   ',',
#   'Business-Management'],
#  ['SQL', ',', 'R', ',', 'Tableau'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Visio'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Marketing',
#   ',',
#   'CI',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'CI'],
#  ['SQL', ',', 'R', ',', 'AI', ',', 'Business-Intelligence'],
#  ['R', ',', 'Excel', ',', 'Visio', ',', 'Microsoft-Word', ',', 'SharePoint'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'SAS', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Jira',
#   ',',
#   'Medical-Insurance',
#   ',',
#   'Business-Management'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'CI',
#   ',',
#   'UI',
#   ',',
#   'Business-Management'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'CI'],
#  ['R', ',', 'Tableau', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'MySQL',
#   ',',
#   'C',
#   '#',
#   ',',
#   'PHP',
#   ',',
#   'PL/SQL',
#   ',',
#   'Pentaho'],
#  ['Python', ',', 'R', ',', 'Data-Analysis', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Network',
#   ',',
#   'PMP'],
#  ['Business-Analysis'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'AWS',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'S3'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'JavaScript',
#   ',',
#   'MySQL',
#   ',',
#   'Power-BI',
#   ',',
#   'CSS'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Azure',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Alteryx'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Marketing', ',', 'SaaS'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Perl',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Data-Management',
#   ',',
#   'Epic',
#   ',',
#   'Managed-Care'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Perl',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Data-Management',
#   ',',
#   'Epic',
#   ',',
#   'Managed-Care'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Go'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Biostatistics'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'SharePoint'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'AI'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Go', ',', 'Google-Analytics'],
#  ['R', ',', 'Tableau', ',', 'Microsoft-Office', ',', 'Excel', ',', 'CI'],
#  ['R', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Oracle', ',', 'Teradata', ',', 'DB2'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'AWS', ',', 'Business-Intelligence'],
#  ['R', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Go'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['R', ',', 'Excel', ',', 'Business-Intelligence', ',', 'Go'],
#  ['R', ',', 'Excel', ',', 'Accounting', ',', 'UI', ',', 'RN'],
#  ['R', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'SAP',
#   ',',
#   'Go'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Clinical-Trials', ',', 'IDS'],
#  ['R', ',', 'Excel', ',', 'Accounting'],
#  ['SQL', ',', 'Tableau', ',', 'Business-Intelligence'],
#  ['R', ',', 'Excel', ',', 'Accounting', ',', 'UI', ',', 'RN'],
#  ['R', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Power-BI'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel', ',', 'Visio', ',', 'GIS'],
#  ['R', ',', 'Big-Data', ',', 'AI', ',', 'Business-Intelligence', ',', 'Go'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Science',
#   ',',
#   'Alteryx'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Marketo'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Network',
#   ',',
#   'Visio',
#   ',',
#   'Epic',
#   ',',
#   'UI',
#   ',',
#   'ACH'],
#  ['SQL', ',', 'R', ',', 'AI'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'SAS', ',', 'Excel', ',', 'ICD-9'],
#  ['SQL', ',', 'SAS', ',', 'Accounting', ',', 'Business-Management'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Go'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'T-SQL',
#   ',',
#   'Quality-Management',
#   ',',
#   'Biostatistics'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Excel',
#   ',',
#   'JavaScript',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['R', ',', 'Tableau', ',', 'Excel', ',', 'Visio', ',', 'Accounting'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Ruby'],
#  ['R', ',', 'Tableau', ',', 'Excel', ',', 'Power-BI', ',', 'Accounting'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'STATA'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'AI'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Marketing',
#   ',',
#   'Business-Management'],
#  ['SQL', ',', 'R', ',', 'Data-Science'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Network',
#   ',',
#   'Go',
#   ',',
#   'Omniture'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Management-Experience'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Git', ',', 'Excel', ',', 'Go'],
#  ['R',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Go',
#   ',',
#   'System-Design',
#   ',',
#   'PMP',
#   ',',
#   'CPA',
#   ',',
#   'Oracle-EBS'],
#  ['R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Power-BI',
#   ',',
#   'Marketing',
#   ',',
#   'Go',
#   ',',
#   'Google-Suite'],
#  ['R'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'AWS',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Marketing',
#   ',',
#   'Alteryx'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'UI'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Microsoft-SQL-Server',
#   ',',
#   'Excel',
#   ',',
#   'MySQL',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Oracle',
#   ',',
#   'Git',
#   ',',
#   'Excel',
#   ',',
#   'JavaScript',
#   ',',
#   'S3',
#   ',',
#   'Teradata',
#   ',',
#   'REST',
#   ',',
#   'XML',
#   ',',
#   'HTML5',
#   ',',
#   'DB2',
#   ',',
#   'CSS',
#   ',',
#   'Angular',
#   ',',
#   'React',
#   ',',
#   'SOAP',
#   ',',
#   'UI',
#   ',',
#   'Tomcat'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Jira',
#   ',',
#   'Visio',
#   ',',
#   'Confluence',
#   ',',
#   'SOX'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Marketo'],
#  ['SDLC', ',', 'Go', ',', 'UI', ',', 'UX'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Digital-Marketing',
#   ',',
#   'Omniture'],
#  ['SQL', ',', 'Tableau', ',', 'Data-Science', ',', 'Go', ',', 'UX'],
#  ['R', ',', 'Excel', ',', 'Perl', ',', 'Epic'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Network'],
#  ['R', ',', 'Excel', ',', 'UI', ',', 'Customer-Service'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Accounting'],
#  ['Python',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Data-Management',
#   ',',
#   'Quantitative-Analysis'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Ruby',
#   ',',
#   'Power-BI'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Linux',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Marketing',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Omniture'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Power-BI'],
#  ['R', ',', 'Excel', ',', 'Marketing', ',', 'Visio'],
#  ['R',
#   ',',
#   'Project-Management',
#   ',',
#   'Jira',
#   ',',
#   'Go',
#   ',',
#   'Software-Testing',
#   ',',
#   'Process-Engineering'],
#  ['R', ',', 'Excel', ',', 'UI'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['R',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'SAP',
#   ',',
#   'Customer-Service'],
#  ['R', ',', 'Tableau', ',', 'Excel', ',', 'Marketing'],
#  ['Python', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Marketing'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Business-Intelligence', ',', 'UI'],
#  ['SQL', ',', 'R', ',', 'Hadoop', ',', 'Tableau', ',', 'Hive', ',', 'Excel'],
#  ['R', ',', 'Tableau', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'JavaScript',
#   ',',
#   'Marketing',
#   ',',
#   'SAP',
#   ',',
#   'Digital-Marketing'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'CI',
#   ',',
#   'Go'],
#  ['R', ',', 'Excel', ',', 'SaaS'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Visio'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Google-Search-Console',
#   ',',
#   'SEO'],
#  ['R'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI'],
#  ['R', ',', 'Marketing'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'UI'],
#  ['R', ',', 'Excel', ',', 'Windows'],
#  ['SQL', ',', 'R', ',', 'Data-Analysis', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R'],
#  ['R', ',', 'Go'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Go'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Omniture'],
#  ['Tableau', ',', 'Excel', ',', 'Business-Intelligence'],
#  ['R', ',', 'Excel', ',', 'CI', ',', 'Go'],
#  ['Excel', ',', 'Business-Analysis'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Business-Intelligence'],
#  ['R', ',', 'Oracle', ',', 'Excel', ',', 'Perl', ',', 'CI', ',', 'PeopleSoft'],
#  ['R', ',', 'Excel', ',', 'Go'],
#  ['R', ',', 'Tableau', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Microsoft-Access',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Customer-Service'],
#  ['SQL', ',', 'R', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Git',
#   ',',
#   'JSON',
#   ',',
#   'Alteryx',
#   ',',
#   'PL/SQL',
#   ',',
#   'React'],
#  ['R', ',', 'Data-Analysis', ',', 'Excel', ',', 'Accounting'],
#  ['R', ',', 'Excel', ',', 'Accounting'],
#  ['R',
#   ',',
#   'Java',
#   ',',
#   'JavaScript',
#   ',',
#   'JSON',
#   ',',
#   'XML',
#   ',',
#   'Analysis-Skills',
#   ',',
#   'Go',
#   ',',
#   'CSS',
#   ',',
#   'UI',
#   ',',
#   'UX',
#   ',',
#   'Drupal',
#   ',',
#   'Magento',
#   ',',
#   'WordPress',
#   ',',
#   'Conflict-Management'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'Visio', ',', 'CI'],
#  ['R'],
#  ['R', ',', 'AI', ',', 'Excel'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Visio',
#   ',',
#   'Epic',
#   ',',
#   'Epic-Certification',
#   ',',
#   'RN'],
#  ['R'],
#  ['R', ',', 'Epidemiology', ',', 'Biostatistics'],
#  ['R', ',', 'Marketing', ',', 'SAP', ',', 'Epic', ',', 'Epic-Certification'],
#  ['R', ',', 'Excel', ',', 'SDLC', ',', 'UI'],
#  ['R', ',', 'Excel', ',', 'SDLC', ',', 'UI'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Power-BI',
#   ',',
#   'Business-Management'],
#  ['R', ',', 'Excel', ',', 'Marketing', ',', 'Visio', ',', 'CI'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'SDLC', ',', 'Jira', ',', 'Visio', ',', 'UI'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence'],
#  ['R', ',', 'Excel', ',', 'SAP', ',', 'Network', ',', 'Accounting'],
#  ['R', ',', 'Excel', ',', 'Power-BI'],
#  ['R', ',', 'Excel', ',', 'Marketing', ',', 'CI'],
#  ['R'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Software-Development',
#   ',',
#   'Visio',
#   ',',
#   'CI',
#   ',',
#   'Go',
#   ',',
#   'UI'],
#  ['R', ',', 'PMP'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Software-Development',
#   ',',
#   'SDLC',
#   ',',
#   'Business-Analysis'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'SAP', ',', 'SOX'],
#  ['SQL', ',', 'R', ',', 'Go', ',', 'Accounting'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Go',
#   ',',
#   'Hyperion',
#   ',',
#   'Google-Suite'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'PMP'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Data-Management'],
#  ['Python', ',', 'SQL', ',', 'Java', ',', 'C/C++', ',', 'Excel'],
#  ['R'],
#  ['R', ',', 'Accounting'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'XML',
#   ',',
#   'Workday',
#   ',',
#   'FTP'],
#  ['SQL', ',', 'R', ',', 'Data-Warehouse', ',', 'Excel'],
#  ['R',
#   ',',
#   'Marketing',
#   ',',
#   'Network',
#   ',',
#   'Go',
#   ',',
#   'Customer-Service',
#   ',',
#   'Managed-Care'],
#  ['R', ',', 'AI', ',', 'UI'],
#  ['Python', ',', 'R', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'Marketing', ',', 'Visio', ',', 'CI', ',', 'RN'],
#  ['R', ',', 'Excel'],
#  ['Python', ',', 'R', ',', 'Git', ',', 'Data-Science'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Accounting'],
#  ['R', ',', 'Tableau', ',', 'Excel', ',', 'SDLC'],
#  ['R', ',', 'Excel', ',', 'SAP', ',', 'Network', ',', 'Accounting'],
#  ['R', ',', 'Excel', ',', 'Accounting', ',', 'RN'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'PostgreSQL', ',', 'MongoDB'],
#  ['R', ',', 'Excel', ',', 'Data-Management'],
#  ['R',
#   ',',
#   'Data-Management',
#   ',',
#   'Accounting',
#   ',',
#   'Regulatory-Reporting',
#   ',',
#   'IFRS'],
#  ['R', ',', 'Data-Science'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'XML',
#   ',',
#   'IDS'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'MySQL',
#   ',',
#   'Go',
#   ',',
#   'SEO'],
#  ['R', ',', 'Excel', ',', 'Go'],
#  ['R',
#   ',',
#   'Marketing',
#   ',',
#   'Network',
#   ',',
#   'Go',
#   ',',
#   'Customer-Service',
#   ',',
#   'Managed-Care'],
#  ['R', ',', 'Power-BI'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'CI',
#   ',',
#   'Accounting',
#   ',',
#   'Customer-Service',
#   ',',
#   'Financial-Accounting',
#   ',',
#   'Payroll'],
#  ['Python', ',', 'R'],
#  ['Python', ',', 'R'],
#  ['R'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Biostatistics'],
#  ['R', ',', 'SAS', ',', 'Epidemiology', ',', 'Biostatistics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Linux',
#   ',',
#   'Perl',
#   ',',
#   'Teradata',
#   ',',
#   'Windows'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'JavaScript',
#   ',',
#   'Google-Cloud-Platform',
#   ',',
#   'Go'],
#  ['R'],
#  ['R', ',', 'Excel'],
#  ['Python',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'JavaScript'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'JSON',
#   ',',
#   'XML',
#   ',',
#   'Go'],
#  ['R', ',', 'Marketing'],
#  ['R', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'NoSQL', ',', 'ICD-10'],
#  ['R'],
#  ['R'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel', ',', 'GIS', ',', 'Accounting'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Operations-Research'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Excel', ',', 'SPSS', ',', 'UI'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Excel', ',', 'CI'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['R', ',', 'SAS', ',', 'AI', ',', 'Excel', ',', 'Epidemiology', ',', 'IDS'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Visual-Basic',
#   ',',
#   'Operations-Research'],
#  ['R', ',', 'Excel', ',', 'UI'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel', ',', 'GIS'],
#  ['R', ',', 'Excel', ',', 'Go'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Marketing', ',', 'Visio', ',', 'Go'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['Python', ',', 'Data-Analysis', ',', 'Excel'],
#  ['Python',
#   ',',
#   'R',
#   ',',
#   'AI',
#   ',',
#   'TensorFlow',
#   ',',
#   'Data-Science',
#   ',',
#   'CI',
#   ',',
#   'Workday',
#   ',',
#   'RN'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'Data-Management', ',', 'CI'],
#  ['R',
#   ',',
#   'Spark',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Data-Management',
#   ',',
#   'CI',
#   ',',
#   'Digital-Marketing',
#   ',',
#   'CPA'],
#  ['SQL', ',', 'Oracle', ',', 'Business-Analysis'],
#  ['R', ',', 'Big-Data'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Excel', ',', 'ICD-10', ',', 'ICD-9'],
#  ['R', ',', 'Data-Management', ',', 'Go'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Quality-Management'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AWS',
#   ',',
#   'Excel',
#   ',',
#   'CI',
#   ',',
#   'Unity'],
#  ['R'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Marketing'],
#  ['R', ',', 'Git', ',', 'Excel', ',', 'Go'],
#  ['SQL', ',', 'R', ',', 'Data-Warehouse', ',', 'Excel', ',', 'JSON'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Workday',
#   ',',
#   'RN'],
#  ['R', ',', 'Tableau', ',', 'Excel', ',', 'Six-Sigma'],
#  ['R', ',', 'SAS', ',', 'Excel', ',', 'Biostatistics'],
#  ['R'],
#  ['Python',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'JavaScript'],
#  ['R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'SAP',
#   ',',
#   'CI',
#   ',',
#   'Payroll'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Go'],
#  ['R', ',', 'RN'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel', ',', 'Informatica'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['SQL', ',', 'SAS', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Hadoop', ',', 'Tableau', ',', 'Excel'],
#  ['R', ',', 'Tableau', ',', 'Excel', ',', 'Data-Management', ',', 'Workday'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Go',
#   ',',
#   'Clinical-Research'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Go', ',', 'FTP'],
#  ['R'],
#  ['R', ',', 'Data-Science', ',', 'Business-Intelligence', ',', 'Epic'],
#  ['R', ',', 'Network', ',', 'UI'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel', ',', 'Visio', ',', 'Audits'],
#  ['R', ',', 'SAS', ',', 'MATLAB'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Data-Management',
#   ',',
#   'Network',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'FTP',
#   ',',
#   'Marketo',
#   ',',
#   'SEO'],
#  ['R', ',', 'Marketing'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Marketing',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Public-Relations'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'SDLC',
#   ',',
#   'Business-Analysis',
#   ',',
#   'CI',
#   ',',
#   'Go',
#   ',',
#   'Troubleshooting'],
#  ['R', ',', 'Excel', ',', 'Marketing', ',', 'Pardot'],
#  ['R',
#   ',',
#   'Data-Management',
#   ',',
#   'Go',
#   ',',
#   'Accounting',
#   ',',
#   'Regulatory-Reporting'],
#  ['R', ',', 'SAS', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI'],
#  ['R', ',', 'Excel'],
#  ['Python',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Excel',
#   ',',
#   'Perl',
#   ',',
#   'Project-Management',
#   ',',
#   'C',
#   '#',
#   ',',
#   'PHP',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Go',
#   ',',
#   'Application-Support'],
#  ['R', ',', 'Excel', ',', 'Marketing', ',', 'Go', ',', 'Google-Analytics'],
#  ['R', ',', 'Excel', ',', 'Perl', ',', 'Epic'],
#  ['R'],
#  ['R'],
#  ['R', ',', 'Excel', ',', 'Microsoft-Word'],
#  ['R', ',', 'Excel'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Java', ',', 'Excel', ',', 'C', '#'],
#  ['SQL'],
#  ['R', ',', 'Microsoft-Office'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'Perl', ',', 'Epic'],
#  ['R', ',', 'AI', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Visual-Basic'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'GIS'],
#  ['R', ',', 'Excel', ',', 'Perl', ',', 'Epic'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Audits',
#   ',',
#   'UI'],
#  ['R'],
#  ['R', ',', 'Excel', ',', 'Microsoft-Access'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel', ',', 'GIS'],
#  ['R', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Excel', ',', 'Network', ',', 'Maven'],
#  ['R', ',', 'Excel', ',', 'STATA'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'Perl', ',', 'Epic'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Microsoft-SQL-Server',
#   ',',
#   'Excel',
#   ',',
#   'C',
#   '#',
#   ',',
#   'Microsoft-Access',
#   ',',
#   'SharePoint'],
#  ['R', ',', 'Excel', ',', 'Perl', ',', 'Epic'],
#  ['Python', ',', 'SQL', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'Go'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'AWS'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'SAS', ',', 'Excel', ',', 'SPSS'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Go'],
#  ['R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Power-BI',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Microsoft-SQL-Server',
#   ',',
#   'Scripting',
#   ',',
#   'Crystal-Reports',
#   ',',
#   'Epic'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'GIS'],
#  ['R', ',', 'AI', ',', 'Data-Analysis'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Oracle', ',', 'Data-Science'],
#  ['R'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'Teradata',
#   ',',
#   'Marketing',
#   ',',
#   'Data-Management',
#   ',',
#   'Visio'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Power-BI'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'STATA',
#   ',',
#   'GIS',
#   ',',
#   'Telecommunication'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Tableau'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Go', ',', 'ACH'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Spark',
#   ',',
#   'SAS',
#   ',',
#   'AWS',
#   ',',
#   'S3',
#   ',',
#   'Visio'],
#  ['R'],
#  ['Python', ',', 'R', ',', 'Hadoop', ',', 'Tableau', ',', 'Go'],
#  ['Python', ',', 'Hadoop', ',', 'Tableau', ',', 'Go'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'SDLC',
#   ',',
#   'Business-Analysis',
#   ',',
#   'CI',
#   ',',
#   'Go',
#   ',',
#   'Troubleshooting'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'AWS', ',', 'Data-Science'],
#  ['R', ',', 'Excel', ',', 'Accounting'],
#  ['Machine-Learning',
#   ',',
#   'R',
#   ',',
#   'Big-Data',
#   ',',
#   'AI',
#   ',',
#   'Data-Analysis',
#   ',',
#   'MATLAB',
#   ',',
#   'Excel',
#   ',',
#   'S3',
#   ',',
#   'Network',
#   ',',
#   'Go',
#   ',',
#   'UI',
#   ',',
#   'SSL'],
#  ['Python',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'Scala',
#   ',',
#   'Go',
#   ',',
#   'Bioinformatics',
#   ',',
#   'Genetics'],
#  ['R',
#   ',',
#   'Data-Management',
#   ',',
#   'SAP',
#   ',',
#   'Process-Management',
#   ',',
#   'Business-Management'],
#  ['R', ',', 'Tableau', ',', 'Excel', ',', 'Go', ',', 'Google-Analytics'],
#  ['R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Data-Management',
#   ',',
#   'Accounting'],
#  ['R', ',', 'AI', ',', 'Excel', ',', 'Marketing'],
#  ['SQL',
#   ',',
#   'Machine-Learning',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Power-BI'],
#  ['Python', ',', 'R', ',', 'SAS', ',', 'Scripting', ',', 'Go', ',', 'Android'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'SAS',
#   ',',
#   'Scala',
#   ',',
#   'Perl',
#   ',',
#   'SPSS',
#   ',',
#   'Network',
#   ',',
#   'Go'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Omniture'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Go', ',', 'Ant'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Spark',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Big-Data',
#   ',',
#   'AWS',
#   ',',
#   'Scala',
#   ',',
#   'NoSQL',
#   ',',
#   'Oracle',
#   ',',
#   'Azure',
#   ',',
#   'MySQL',
#   ',',
#   'Data-Science',
#   ',',
#   'S3',
#   ',',
#   'Google-Cloud-Platform',
#   ',',
#   'Jira',
#   ',',
#   'Apache',
#   ',',
#   'Go',
#   ',',
#   'Confluence'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Statistical-Software',
#   ',',
#   'Alteryx',
#   ',',
#   'QlikView',
#   ',',
#   'DB2',
#   ',',
#   'Go',
#   ',',
#   'Operations-Research'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AWS',
#   ',',
#   'Operations-Research'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Big-Data',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Customer-Segmentation'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Git', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AWS',
#   ',',
#   'AI',
#   ',',
#   'Data-Science',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'SaaS'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'STATA',
#   ',',
#   'Epidemiology',
#   ',',
#   'Ant',
#   ',',
#   'Biostatistics'],
#  ['R', ',', 'Excel', ',', 'Data-Science', ',', 'Business-Intelligence'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'JavaScript',
#   ',',
#   'Business-Intelligence'],
#  ['Excel', ',', 'Network', ',', 'Go', ',', 'UI'],
#  ['R'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Data-Science'],
#  ['R',
#   ',',
#   'Project-Management',
#   ',',
#   'SDLC',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Go'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Accounting', ',', 'Epic', ',', 'UI'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Excel',
#   ',',
#   'Informatica',
#   ',',
#   'Alteryx'],
#  ['R', ',', 'Excel'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Analysis',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Data-Management',
#   ',',
#   'SAP'],
#  ['SQL', ',', 'R', ',', 'PowerShell', ',', 'Windows'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'QlikView'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Go',
#   ',',
#   'PMP'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'NoSQL',
#   ',',
#   'Excel',
#   ',',
#   'Marketing'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'CI',
#   ',',
#   'Go',
#   ',',
#   'Telecommunication',
#   ',',
#   'IAT',
#   ',',
#   'ACH'],
#  ['SQL', ',', 'R', ',', 'Data-Analysis'],
#  ['R', ',', 'Excel', ',', 'Marketing'],
#  ['R', ',', 'Excel', ',', 'SDLC', ',', 'Visio'],
#  ['Tableau', ',', 'Excel', ',', 'Go', ',', 'Google-Analytics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Google-Cloud-Platform',
#   ',',
#   'Go',
#   ',',
#   'Confluence',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Omniture',
#   ',',
#   'Doubleclick',
#   ',',
#   'iOS',
#   ',',
#   'Android'],
#  ['R'],
#  ['SQL', ',', 'R', ',', 'AI', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['R', ',', 'SAS', ',', 'Excel', ',', 'Microsoft-Access', ',', 'Network'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'AWS',
#   ',',
#   'Azure',
#   ',',
#   'HBase',
#   ',',
#   'MongoDB',
#   ',',
#   'Ruby',
#   ',',
#   'Elasticsearch',
#   ',',
#   'REST',
#   ',',
#   'Jenkins',
#   ',',
#   'Solr',
#   ',',
#   'Angular',
#   ',',
#   'Maven',
#   ',',
#   'Ansible',
#   ',',
#   'Redis',
#   ',',
#   'Lucene',
#   ',',
#   'Spring',
#   ',',
#   'Bootstrap',
#   ',',
#   'SSL'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Excel'],
#  ['R', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'AWS',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Marketing-Mix-Modeling'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'SAP',
#   ',',
#   'Go',
#   ',',
#   'Crystal-Reports',
#   ',',
#   'Accounting',
#   ',',
#   'Payroll'],
#  ['R', ',', 'Excel'],
#  ['R'],
#  ['Python',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'JavaScript',
#   ',',
#   'CSS',
#   ',',
#   'UI'],
#  ['R'],
#  ['R'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'SDLC',
#   ',',
#   'Go'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Ruby'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Machine-Learning',
#   ',',
#   'R',
#   ',',
#   'Spark',
#   ',',
#   'SAS',
#   ',',
#   'Scala',
#   ',',
#   'MATLAB',
#   ',',
#   'Data-Science',
#   ',',
#   'STATA'],
#  ['R', ',', 'Excel', ',', 'Microsoft-Word', ',', 'Accounting'],
#  ['Python', ',', 'R', ',', 'Marketing'],
#  ['R', ',', 'Excel', ',', 'STATA'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'JSON',
#   ',',
#   'Go',
#   ',',
#   'UI'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Azure',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Marketing',
#   ',',
#   'Visio',
#   ',',
#   'Go',
#   ',',
#   'Adobe-Marketing'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Marketing', ',', 'Adobe-Marketing'],
#  ['R', ',', 'Excel'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Visio',
#   ',',
#   'CI',
#   ',',
#   'Microsoft-Word',
#   ',',
#   'Process-Improvement'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'CI',
#   ',',
#   'CSS',
#   ',',
#   'Managed-Care',
#   ',',
#   'Regulatory-Reporting'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Power-BI',
#   ',',
#   'Alteryx',
#   ',',
#   'CI',
#   ',',
#   'Accounting',
#   ',',
#   'CPA',
#   ',',
#   'CFE'],
#  ['Excel', ',', 'SDLC'],
#  ['SQL', ',', 'R', ',', 'Data-Analysis', ',', 'Excel', ',', 'Visio'],
#  ['R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'AI',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Informatica',
#   ',',
#   'Teradata',
#   ',',
#   'Data-Management',
#   ',',
#   'HTML5',
#   ',',
#   'Go',
#   ',',
#   'CSS'],
#  ['R', ',', 'Excel', ',', 'Perl', ',', 'Epic'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Power-BI',
#   ',',
#   'Marketing',
#   ',',
#   'Go',
#   ',',
#   'Accounting',
#   ',',
#   'PeopleSoft',
#   ',',
#   'Managed-Care',
#   ',',
#   'GAAP'],
#  ['R', ',', 'Excel', ',', 'SDLC', ',', 'Visio'],
#  ['SQL', ',', 'R', ',', 'AI', ',', 'UI'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Excel',
#   ',',
#   'Perl',
#   ',',
#   'Software-Development',
#   ',',
#   'C',
#   '#',
#   ',',
#   'DB2',
#   ',',
#   'Sybase'],
#  ['R', ',', 'Excel', ',', 'SaaS'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Data-Science'],
#  ['R',
#   ',',
#   'Spark',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Data-Management',
#   ',',
#   'CI',
#   ',',
#   'Digital-Marketing',
#   ',',
#   'UI',
#   ',',
#   'CPA'],
#  ['R', ',', 'Excel', ',', 'Accounting'],
#  ['R', ',', 'Tableau', ',', 'Excel', ',', 'Go', ',', 'ITIL'],
#  ['R', ',', 'CI'],
#  ['R', ',', 'Excel', ',', 'SAP', ',', 'Network'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'SPSS', ',', 'Power-BI', ',', 'Visio'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Oracle',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'PostgreSQL',
#   ',',
#   'MySQL',
#   ',',
#   'Crystal-Reports',
#   ',',
#   'Epic',
#   ',',
#   'Quality-Management',
#   ',',
#   'Cerner',
#   ',',
#   'IDS'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['Machine-Learning', ',', 'R', ',', 'Data-Science'],
#  ['SQL', ',', 'R', ',', 'Project-Management', ',', 'Business-Analysis'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Microsoft-SQL-Server',
#   ',',
#   'Excel',
#   ',',
#   'MySQL',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Git',
#   ',',
#   'Excel',
#   ',',
#   'JavaScript',
#   ',',
#   'Data-Science',
#   ',',
#   'Splunk',
#   ',',
#   'XML',
#   ',',
#   'PHP',
#   ',',
#   'HTML5',
#   ',',
#   'Go',
#   ',',
#   'CSS',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Omniture',
#   ',',
#   'Google-Search-Console',
#   ',',
#   'SEO'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Hadoop',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'SPSS',
#   ',',
#   'Business-Intelligence'],
#  ['R', ',', 'Excel', ',', 'CI', ',', 'Go', ',', 'IAT', ',', 'ACH'],
#  ['R', ',', 'Visio', ',', 'FTP', ',', 'Windows'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'SAS', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Oracle',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'PL/SQL',
#   ',',
#   'PeopleSoft'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Clinical-Trials', ',', 'IDS'],
#  ['R'],
#  ['R', ',', 'Accounting', ',', 'Business-Management'],
#  ['R', ',', 'Excel', ',', 'Accounting', ',', 'UI'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Data-Management',
#   ',',
#   'UI'],
#  ['Business-Analysis'],
#  ['R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Marketing',
#   ',',
#   'SharePoint'],
#  ['R', ',', 'Business-Analysis', ',', 'Go'],
#  ['SQL', ',', 'Excel'],
#  ['R', ',', 'Business-Analysis', ',', 'Visio'],
#  ['R', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Data-Management',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Accounting'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'C/C++',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Go'],
#  ['R'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Marketing',
#   ',',
#   'Business-Analysis',
#   ',',
#   'CI'],
#  ['R', ',', 'Oracle', ',', 'Excel', ',', 'Go', ',', 'Salesforce-CRM'],
#  ['R'],
#  ['R',
#   ',',
#   'Data-Analysis',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Microsoft-Project'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Machine-Learning',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AWS',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Informatica',
#   ',',
#   'Marketing',
#   ',',
#   'Alteryx',
#   ',',
#   'Network',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Digital-Marketing'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Visio',
#   ',',
#   'Adobe-Creative-Suite'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Linux',
#   ',',
#   'Excel',
#   ',',
#   'Microsoft-Access',
#   ',',
#   'Windows'],
#  ['R', ',', 'Excel', ',', 'Microsoft-Word'],
#  ['R'],
#  ['R'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'SAS', ',', 'Excel', ',', 'Marketing'],
#  ['R', ',', 'Excel', ',', 'Business-Intelligence'],
#  ['R', ',', 'Tableau', ',', 'Go', ',', 'Google-Analytics'],
#  ['R', ',', 'Excel', ',', 'Accounting'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Go',
#   ',',
#   'PeopleSoft'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence'],
#  ['R', ',', 'Excel', ',', 'UX'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Hadoop',
#   ',',
#   'Spark',
#   ',',
#   'Tableau',
#   ',',
#   'Hive',
#   ',',
#   'NoSQL',
#   ',',
#   'Kafka',
#   ',',
#   'Excel',
#   ',',
# ...
#   ',',
#   'IFRS'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Hadoop',
#   ',',
#   'Hive',
#   ',',
#   'SAS',
#   ',',
#   'Data-Science',
#   ',',
#   'PHP'],
#  ['R', ',', 'Excel', ',', 'Business-Intelligence', ',', 'Time-Management'],
#  ['R', ',', 'Excel', ',', 'Regulatory-Reporting'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Marketing'],
#  ['R', ',', 'Excel', ',', 'Business-Analysis', ',', 'IaaS'],
#  ['SQL',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'JavaScript',
#   ',',
#   'MySQL',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Omniture'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Perl',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'PHP',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'UX'],
#  ['R', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'Software-Development', ',', 'Visio'],
#  ['SQL', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Visio',
#   ',',
#   'CSS',
#   ',',
#   'RN',
#   ',',
#   'WordPress'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Biostatistics'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'AI',
#   ',',
#   'JavaScript',
#   ',',
#   'Marketing'],
#  ['R', ',', 'Marketing', ',', 'Go', ',', 'SEO'],
#  ['R', ',', 'Excel', ',', 'Accounting', ',', 'Audits'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'SAP',
#   ',',
#   'Go'],
#  ['R', ',', 'SAP'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Software-Development',
#   ',',
#   'SDLC',
#   ',',
#   'Visio'],
#  ['Python', ',', 'SQL', ',', 'R'],
#  ['R', ',', 'SDLC', ',', 'Network', ',', 'Go'],
#  ['R'],
#  ['SQL', ',', 'R', ',', '.Net', ',', 'C', '#', ',', 'Jira', ',', 'Confluence'],
#  ['R', ',', 'Excel', ',', 'Project-Management', ',', 'CI', ',', 'SharePoint'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Network',
#   ',',
#   'Go',
#   ',',
#   'Application-Support',
#   ',',
#   'RN'],
#  ['R', ',', 'Excel'],
#  ['R',
#   ',',
#   'Azure',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Visio',
#   ',',
#   'SaaS',
#   ',',
#   'UI'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Clinical-Trials', ',', 'IDS'],
#  ['R',
#   ',',
#   'AI',
#   ',',
#   'SAP',
#   ',',
#   'Operations-Research',
#   ',',
#   'Business-Management'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Visual-Basic',
#   ',',
#   'Visio',
#   ',',
#   'SharePoint',
#   ',',
#   'Kanban',
#   ',',
#   'VersionOne'],
#  ['R',
#   ',',
#   'Spark',
#   ',',
#   'Tableau',
#   ',',
#   'AWS',
#   ',',
#   'Linux',
#   ',',
#   'Excel',
#   ',',
#   'Docker',
#   ',',
#   'C',
#   '#',
#   ',',
#   'Power-BI',
#   ',',
#   'Apache',
#   ',',
#   'Go'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'AWS', ',', 'S3', ',', 'Visio'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Marketing',
#   ',',
#   'Jira',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Digital-Marketing',
#   ',',
#   'Accounting',
#   ',',
#   'Adobe-Acrobat'],
#  ['R', ',', 'Excel', ',', 'Network', ',', 'Go'],
#  ['R', ',', 'Excel', ',', 'SaaS'],
#  ['R'],
#  ['SQL', ',', 'R'],
#  ['R'],
#  ['Python',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'AWS',
#   ',',
#   'Azure',
#   ',',
#   'Excel',
#   ',',
#   'Perl',
#   ',',
#   'Ruby',
#   ',',
#   'Google-Cloud-Platform',
#   ',',
#   'Go',
#   ',',
#   'SaaS'],
#  ['R', ',', 'AI'],
#  ['R',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Change-Management'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Omniture'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Visio',
#   ',',
#   'SharePoint'],
#  ['R', ',', 'AI', ',', 'Project-Management', ',', 'Go'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Software-Development',
#   ',',
#   'Project-Management',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Visio',
#   ',',
#   'Go',
#   ',',
#   'UI'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'XML',
#   ',',
#   'PL/SQL',
#   ',',
#   'OBIEE',
#   ',',
#   'PeopleSoft',
#   ',',
#   'UX',
#   ',',
#   'Windows'],
#  ['R', ',', 'Excel', ',', 'Marketing', ',', 'Accounting'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Jira'],
#  ['R', ',', 'Visio'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Oracle',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'MySQL',
#   ',',
#   'Windows',
#   ',',
#   'Ellucian'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Big-Data',
#   ',',
#   'Oracle',
#   ',',
#   'Azure',
#   ',',
#   'Excel',
#   ',',
#   'Teradata',
#   ',',
#   'Data-Management'],
#  ['R', ',', 'Accounting', ',', 'SaaS', ',', 'Payroll'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'SAS', ',', 'Teradata'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Time-Management'],
#  ['SQL', ',', 'R', ',', 'AI', ',', 'Business-Analysis', ',', 'UX'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Alteryx',
#   ',',
#   'Accounting',
#   ',',
#   'CPA'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Oracle',
#   ',',
#   'MATLAB',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'SPSS',
#   ',',
#   'Data-Science',
#   ',',
#   'Power-BI',
#   ',',
#   'Marketing',
#   ',',
#   'PL/SQL'],
#  ['R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Marketing',
#   ',',
#   'SharePoint'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Software-Development',
#   ',',
#   'SDLC',
#   ',',
#   'Visio'],
#  ['R', ',', 'SAP'],
#  ['R', ',', 'Excel', ',', 'Accounting', ',', 'Audits'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Splunk',
#   ',',
#   'SharePoint',
#   ',',
#   'Information-Security'],
#  ['Python', ',', 'SQL', ',', 'R'],
#  ['Python',
#   ',',
#   'Machine-Learning',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'QlikView',
#   ',',
#   'CI'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'AI',
#   ',',
#   'JavaScript',
#   ',',
#   'Marketing'],
#  ['SQL', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Excel'],
#  ['SQL', ',', 'Tableau', ',', 'Excel', ',', 'Power-BI'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Go'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Go'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'SAP', ',', 'Visio'],
#  ['SQL', ',', 'R'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Oracle',
#   ',',
#   'Excel',
#   ',',
#   'PostgreSQL',
#   ',',
#   'MySQL',
#   ',',
#   'Informatica'],
#  ['R', ',', 'Excel', ',', 'TFS', ',', 'PMP'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Network',
#   ',',
#   'Go',
#   ',',
#   'Application-Support',
#   ',',
#   'RN'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-SQL-Server',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'C',
#   '#',
#   ',',
#   'PowerShell',
#   ',',
#   'Accounting'],
#  ['R', ',', 'Project-Management', ',', 'SharePoint'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Visio',
#   ',',
#   'CSS',
#   ',',
#   'RN',
#   ',',
#   'WordPress'],
#  ['Software-Development', ',', '.Net', ',', 'C', '#', ',', 'SharePoint'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'Business-Intelligence'],
#  ['R'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Accounting'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Hadoop',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Data-Management'],
#  ['SQL', ',', 'R', ',', 'PowerShell', ',', 'Windows'],
#  ['R', ',', 'Excel', ',', 'Visio', ',', 'Hyperion'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'JSON',
#   ',',
#   'XML',
#   ',',
#   'Go',
#   ',',
#   'Regulatory-Reporting'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Business-Intelligence'],
#  ['R', ',', 'AI', ',', 'Project-Management', ',', 'Go'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Analysis',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Marketing',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Marketing-Automation',
#   ',',
#   'Salesforce-Marketing-Cloud'],
#  ['SQL', ',', 'Tableau', ',', 'Oracle', ',', 'Ant'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Excel'],
#  ['R', ',', 'Excel', ',', 'SPSS', ',', 'Marketing', ',', 'Go'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'Tableau', ',', 'SAS', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'XML',
#   ',',
#   'Visio',
#   ',',
#   'Go',
#   ',',
#   'Application-Support'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'Visio',
#   ',',
#   'CI',
#   ',',
#   'Go',
#   ',',
#   'Epic',
#   ',',
#   'Software-Testing'],
#  ['SQL', ',', 'R', ',', 'Oracle', ',', 'Excel', ',', 'UI'],
#  ['Python', ',', 'SQL', ',', 'R', ',', 'AWS', ',', 'S3', ',', 'Visio'],
#  ['R',
#   ',',
#   'AI',
#   ',',
#   'SAP',
#   ',',
#   'Operations-Research',
#   ',',
#   'Business-Management'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Google-Cloud-Platform',
#   ',',
#   'Go',
#   ',',
#   'Accounting'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'SAP',
#   ',',
#   'Go'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel'],
#  ['SQL', ',', 'R', ',', 'SAS', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Quality-Management',
#   ',',
#   'Managed-Care'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Visio', ',', 'CI', ',', 'SharePoint'],
#  ['R', ',', 'Microsoft-Office', ',', 'Excel', ',', 'UI'],
#  ['SQL', ',', 'R', ',', 'AI', ',', 'Business-Analysis', ',', 'UX'],
#  ['R', ',', 'AI', ',', 'Excel', ',', 'Accounting', ',', 'IDS'],
#  ['R', ',', 'Marketing', ',', 'Go', ',', 'SEO'],
#  ['R', ',', 'Excel'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'SAP',
#   ',',
#   'Go',
#   ',',
#   'SaaS',
#   ',',
#   'Social-Media-Management'],
#  ['R',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Change-Management'],
#  ['R', ',', 'AI', ',', 'UI'],
#  ['R'],
#  ['R',
#   ',',
#   'Azure',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Visio',
#   ',',
#   'SaaS',
#   ',',
#   'UI'],
#  ['SQL', ',', 'R', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Big-Data',
#   ',',
#   'Oracle',
#   ',',
#   'Azure',
#   ',',
#   'Excel',
#   ',',
#   'Teradata',
#   ',',
#   'Data-Management'],
#  ['R', ',', 'Excel', ',', 'Marketing', ',', 'Accounting'],
#  ['R', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel'],
#  ['R'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AI',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Network'],
#  ['R', ',', 'Excel'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Git',
#   ',',
#   'Perl',
#   ',',
#   'Splunk',
#   ',',
#   'Jenkins',
#   ',',
#   'Kubernetes',
#   ',',
#   'SVN',
#   ',',
#   'Chef'],
#  ['R', ',', 'Excel'],
#  ['SQL', ',', 'R', ',', 'REST', ',', 'Visio', ',', 'Process-Management'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'SAS',
#   ',',
#   'Excel',
#   ',',
#   'Visual-Basic',
#   ',',
#   'Visio',
#   ',',
#   'SharePoint',
#   ',',
#   'Kanban',
#   ',',
#   'VersionOne'],
#  ['R', ',', 'Excel'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Jira'],
#  ['Excel'],
#  ['R', ',', 'SDLC', ',', 'Network', ',', 'Go'],
#  ['SQL', ',', 'R', ',', 'Tableau', ',', 'Excel', ',', 'Power-BI'],
#  ['R',
#   ',',
#   'CI',
#   ',',
#   'SharePoint',
#   ',',
#   'Lean',
#   ',',
#   'Six-Sigma',
#   ',',
#   'Business-Management'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'UI'],
#  ['R', ',', 'Excel', ',', 'Business-Analysis', ',', 'UX'],
#  ['R', ',', 'Accounting', ',', 'SaaS', ',', 'Payroll'],
#  ['R'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Marketing',
#   ',',
#   'Jira',
#   ',',
#   'Go',
#   ',',
#   'Google-Analytics',
#   ',',
#   'Digital-Marketing',
#   ',',
#   'Accounting',
#   ',',
#   'Adobe-Acrobat'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence'],
#  ['R', ',', 'Excel', ',', 'SaaS'],
#  ['SQL', ',', 'R', ',', 'Marketing', ',', 'Performance-Marketing', ',', 'SEO'],
#  ['R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Accounting'],
#  ['R',
#   ',',
#   'Excel',
#   ',',
#   'Software-Development',
#   ',',
#   'Project-Management',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Visio',
#   ',',
#   'Go',
#   ',',
#   'UI'],
#  ['R',
#   ',',
#   'Software-Development',
#   ',',
#   'SDLC',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Microsoft-Project',
#   ',',
#   'HP-ALM',
#   ',',
#   'VersionOne'],
#  ['R', ',', 'Excel', ',', 'Lean', ',', 'Six-Sigma'],
#  ['R', ',', 'Jira'],
#  ['R', ',', 'Workday'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'SAS',
#   ',',
#   'NoSQL',
#   ',',
#   'MATLAB',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'STATA',
#   ',',
#   'Go',
#   ',',
#   'ACH'],
#  ['R',
#   ',',
#   'Spark',
#   ',',
#   'Tableau',
#   ',',
#   'AWS',
#   ',',
#   'Linux',
#   ',',
#   'Excel',
#   ',',
#   'Docker',
#   ',',
#   'C',
#   '#',
#   ',',
#   'Power-BI',
#   ',',
#   'Apache',
#   ',',
#   'Go'],
#  ['SQL', ',', 'R', ',', '.Net', ',', 'C', '#', ',', 'Jira', ',', 'Confluence'],
#  ['R',
#   ',',
#   'Marketing',
#   ',',
#   'Business-Analysis',
#   ',',
#   'Adobe-Marketing',
#   ',',
#   'Change-Management'],
#  ['R'],
#  ['SQL', ',', 'R', ',', 'Excel', ',', 'Microsoft-Access', ',', 'Accounting'],
#  ['R', ',', 'Visio'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'Excel',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Omniture'],
#  ['R',
#   ',',
#   'AI',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Project-Management',
#   ',',
#   'CI',
#   ',',
#   'PeopleSoft',
#   ',',
#   'Program-Management'],
#  ['R', ',', 'Oracle', ',', 'Excel', ',', 'Perl', ',', 'CI', ',', 'PeopleSoft'],
#  ['Machine-Learning',
#   ',',
#   'R',
#   ',',
#   'Tableau',
#   ',',
#   'AWS',
#   ',',
#   'Natural-Language-Processing',
#   ',',
#   'AI',
#   ',',
#   'Excel',
#   ',',
#   'Data-Science',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Accounting'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'Hadoop',
#   ',',
#   'Spark',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Big-Data',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Linux',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Informatica'],
#  ['Python',
#   ',',
#   'SQL',
#   ',',
#   'R',
#   ',',
#   'Java',
#   ',',
#   'Tableau',
#   ',',
#   'Big-Data',
#   ',',
#   'Data-Warehouse',
#   ',',
#   'Linux',
#   ',',
#   'JavaScript',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'C',
#   '#',
#   ',',
#   'Informatica',
#   ',',
#   'QlikView',
#   ',',
#   'CSS',
#   ',',
#   'Angular',
#   ',',
#   'Node.js'],
#  ['R',
#   ',',
#   'Microsoft-Office',
#   ',',
#   'Excel',
#   ',',
#   'Marketing',
#   ',',
#   'CI',
#   ',',
#   'Go',
#   ',',
#   'Epic'],
#  ['R', ',', 'Excel', ',', 'CPA', ',', 'GAAP'],
#  ['R', ',', 'Perl', ',', 'Jira', ',', 'Selenium', ',', 'LDAP'],
#  ['R', ',', 'Excel', ',', 'SDLC', ',', 'Visio'],
#  ['R', ',', 'Go'],
#  ['SQL', ',', 'R', ',', 'AI', ',', 'Microsoft-Office', ',', 'Excel'],
#  ['R'],
#  ['SQL',
#   ',',
#   'R',
#   ',',
#   'Azure',
#   ',',
#   'Business-Intelligence',
#   ',',
#   'Power-BI',
#   ',',
#   'Data-Management']]

# %%
for row in tokenized_sents:
    for i in row:
        if i == ',':
            row.remove(i)

# %%
tokenized_sents
# Out:
# [['Python',
#   'SQL',
#   'R',
#   'Spark',
#   'Hive',
#   'AWS',
#   'Data-Warehouse',
#   'Business-Intelligence',
#   'Network'],
#  ['SQL', 'R', 'Excel', 'Network'],
#  ['R', 'Excel'],
#  ['R', 'Microsoft-Office', 'Excel', 'Marketing'],
#  ['R'],
#  ['R'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'AWS',
#   'Data-Analysis',
#   'PostgreSQL',
#   'MySQL',
#   'S3',
#   'SaaS',
#   'SSH',
#   'Tomcat'],
#  ['R', 'Excel'],
#  ['R', 'Microsoft-Office', 'Excel', 'Go'],
#  ['R'],
#  ['SQL', 'R', 'Marketing', 'CSS', 'WordPress'],
#  ['Software-Development', '.Net', 'C', '#', 'SharePoint'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Linux',
#   'Go',
#   'CSS',
#   'GIS',
#   'Google-Analytics',
#   'Omniture',
#   'Workday'],
#  ['R'],
#  ['SQL', 'R'],
#  ['Python', 'R', 'Excel'],
#  ['SQL', 'R', 'SAS', 'MATLAB', 'Data-Science', 'Go'],
#  ['SQL', 'R', 'Excel'],
#  ['Python', 'SQL', 'R', 'Spark', 'SDLC'],
#  ['SQL', 'R', 'Microsoft-Office', 'Excel', 'Project-Management', 'Accounting'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Hive', 'Excel', 'Workday'],
#  ['Python', 'SQL', 'R', 'Java', 'Tableau', 'SAS', 'Excel'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Microsoft-Office', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'Excel'],
#  ['Python', 'SQL', 'Tableau', 'Scala', 'Marketing'],
#  ['R', 'Excel', 'SPSS', 'Marketing', 'Go'],
#  ['SQL', 'R', 'Excel', 'Marketing', 'Go', 'Google-Analytics'],
#  ['Python',
#   'SQL',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Go',
#   'Google-Analytics'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Go'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Excel', 'SPSS', 'Marketing'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Excel',
#   'Microsoft-Word',
#   'Operations-Research'],
#  ['SQL', 'R', 'Excel'],
#  ['Python', 'SQL', 'R'],
#  ['Python', 'SQL', 'R', 'Excel'],
#  ['Python', 'SQL', 'R', 'Go', 'Google-Analytics'],
#  ['SQL', 'R', 'Excel', 'SPSS', 'CI', 'Go', 'NIST'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go', 'Google-Analytics'],
#  ['Python', 'SQL', 'R', 'SAS', 'AI', 'Microsoft-Office', 'Excel', 'IDS'],
#  ['R', 'Excel', 'Network'],
#  ['SQL', 'R', 'SAS', 'Microsoft-Office', 'Excel'],
#  ['Python', 'SQL', 'R', 'Tableau', 'SAS', 'Excel'],
#  ['SQL', 'R', 'Excel', 'Visio', 'CI', 'SharePoint'],
#  ['R', 'Microsoft-Office', 'Excel', 'UI'],
#  ['SQL', 'R'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['Python', 'SQL', 'R', 'Tableau'],
#  ['R', 'Excel', 'Quality-Management'],
#  ['Python', 'SQL', 'Tableau', 'Google-Cloud-Platform', 'Go', 'Accounting'],
#  ['Python', 'R', 'Go'],
#  ['R', 'Network', 'UI'],
#  ['R', 'Excel', 'Perl', 'Epic'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Marketing',
#   'SaaS',
#   'Marketo'],
#  ['R', 'Excel', 'Accounting', 'Audits'],
#  ['SQL',
#   'R',
#   'Excel',
#   'Project-Management',
#   'XML',
#   'Visio',
#   'Go',
#   'Application-Support'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel'],
#  ['R',
#   'Tableau',
#   'Excel',
#   'Perl',
#   'Business-Intelligence',
#   'Data-Management',
#   'Epic',
#   'Managed-Care'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Go',
#   'iOS',
#   'Android'],
#  ['R'],
#  ['SQL',
#   'R',
#   'Hadoop',
#   'Java',
#   'Tableau',
#   'SAS',
#   'Microsoft-Office',
#   'Excel',
#   'Go'],
#  ['Python', 'SQL', 'R', 'Scala', 'Excel'],
#  ['Python', 'SQL', 'AI', 'Excel', 'Data-Science', 'Biostatistics'],
#  ['Python', 'SQL', 'R', 'Linux', 'Excel', 'CI', 'Accounting'],
#  ['Python', 'SQL', 'AI', 'Excel', 'Data-Science', 'Biostatistics'],
#  ['Python',
#   'SQL',
#   'R',
#   'Hadoop',
#   'Tableau',
#   'Hive',
#   'SAS',
#   'Big-Data',
#   'Linux',
#   'Marketing',
#   'Digital-Marketing'],
#  ['Python',
#   'SQL',
#   'Machine-Learning',
#   'R',
#   'Spark',
#   'SAS',
#   'Scala',
#   'MATLAB',
#   'Data-Science',
#   'STATA'],
#  ['Python', 'SQL', 'R', 'Go', 'Google-Analytics'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel'],
#  ['Python', 'SQL', 'R', 'SAS', 'Excel'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel', 'Business-Intelligence', 'Go'],
#  ['Python', 'SQL', 'R', 'AWS', 'Data-Science', 'S3', 'GIS', 'PostGIS'],
#  ['Data-Analysis', 'Excel', 'Business-Intelligence'],
#  ['Python', 'SQL', 'R', 'Marketing'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Microsoft-Office', 'Excel', 'SPSS', 'Go'],
#  ['Python', 'SQL', 'R', 'Excel'],
#  ['Python', 'SQL', 'R', 'Java', 'Tableau', 'Oracle', 'Excel', 'Go'],
#  ['R', 'Tableau', 'Excel', 'Business-Intelligence', 'Jira', 'iOS'],
#  ['Python', 'R', 'Git', 'C', '#', 'Quantitative-Research'],
#  ['SQL', 'R', 'SAS', 'Excel', 'Quality-Management', 'Managed-Care'],
#  ['Python',
#   'SQL',
#   'R',
#   'Hadoop',
#   'Tableau',
#   'SAS',
#   'AWS',
#   'Excel',
#   'SPSS',
#   'Business-Intelligence',
#   'Informatica',
#   'Data-Management',
#   'Apache',
#   'SAP',
#   'Predictive-Analytics',
#   'OBIEE'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Scripting', 'SPSS'],
#  ['Python', 'R', 'Tableau', 'Informatica'],
#  ['Python', 'SQL', 'R', 'Excel', 'Data-Science', 'SaaS'],
#  ['Python', 'SQL', 'R', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Microsoft-SQL-Server',
#   'Microsoft-Office',
#   'Excel',
#   'C',
#   '#',
#   'PowerShell',
#   'Accounting'],
#  ['Python', 'SQL', 'R', 'Java', 'Tableau', 'Oracle', 'Excel'],
#  ['Python', 'SQL', 'R', 'Oracle', 'Excel', 'Go', 'Clojure'],
#  ['Python', 'SQL', 'R', 'SAS', 'Data-Science'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Microsoft-Office',
#   'Excel',
#   'Salesforce-CRM'],
#  ['Python',
#   'SQL',
#   'R',
#   'Excel',
#   'Project-Management',
#   'Marketing',
#   'Business-Management'],
#  ['SQL',
#   'R',
#   'Spark',
#   'Big-Data',
#   'AWS',
#   'Data-Science',
#   'Go',
#   'iOS',
#   'Android'],
#  ['Python', 'SQL', 'R', 'Excel'],
#  ['SQL', 'R', 'Oracle', 'Excel', 'SDLC'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['Python', 'SQL', 'R', 'Microsoft-Office', 'Excel', 'SPSS', 'Visio', 'SEO'],
#  ['Python', 'SQL', 'Microsoft-Office', 'Excel', 'Business-Intelligence'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'Oracle',
#   'Excel',
#   'JavaScript',
#   'Marketing',
#   'SAP',
#   'Digital-Marketing'],
#  ['SQL', 'R', 'Business-Intelligence'],
#  ['R', 'Excel', 'Business-Management'],
#  ['SQL', 'R', 'Tableau', 'AI', 'Excel', 'SAP'],
#  ['R', 'Microsoft-Office', 'Excel', 'Marketing'],
#  ['Python',
#   'SQL',
#   'R',
#   'Excel',
#   'Project-Management',
#   'Marketing',
#   'Business-Management'],
#  ['R', 'Microsoft-Office', 'Excel'],
#  ['R', 'Marketing', 'SharePoint'],
#  ['R', 'Tableau', 'Go'],
#  ['R', 'Excel', 'Marketing', 'SAP', 'Go', 'React', 'Epic', 'PeopleSoft'],
#  ['R', 'Project-Management'],
#  ['SQL', 'R', 'Excel', 'SPSS', 'CI', 'Go', 'NIST'],
#  ['R', 'SAS', 'Excel', 'Marketing'],
#  ['R', 'Excel', 'Microsoft-Word', 'Accounting', 'Managed-Care'],
#  ['SQL', 'R', 'Excel', 'UI'],
#  ['R'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Data-Science', 'Business-Intelligence'],
#  ['R'],
#  ['R',
#   'Excel',
#   'Business-Intelligence',
#   'Power-BI',
#   'Medical-Insurance',
#   'Business-Management'],
#  ['SQL', 'R', 'Tableau'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'Data-Science',
#   'Business-Intelligence',
#   'Visio'],
#  ['SQL', 'R', 'Tableau', 'Marketing', 'CI', 'Go', 'Google-Analytics'],
#  ['Python',
#   'SQL',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Go',
#   'Google-Analytics'],
#  ['R', 'Microsoft-Office', 'Excel', 'CI'],
#  ['SQL', 'R', 'AI', 'Business-Intelligence'],
#  ['R', 'Excel', 'Visio', 'Microsoft-Word', 'SharePoint'],
#  ['Python', 'SQL', 'R', 'SAS', 'Excel'],
#  ['Python',
#   'SQL',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Go',
#   'Google-Analytics'],
#  ['R',
#   'Microsoft-Office',
#   'Excel',
#   'Jira',
#   'Medical-Insurance',
#   'Business-Management'],
#  ['R', 'Tableau', 'Excel', 'SPSS', 'CI', 'UI', 'Business-Management'],
#  ['R', 'Microsoft-Office', 'Excel', 'CI'],
#  ['R', 'Tableau', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Oracle',
#   'Excel',
#   'MySQL',
#   'C',
#   '#',
#   'PHP',
#   'PL/SQL',
#   'Pentaho'],
#  ['Python', 'R', 'Data-Analysis', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Excel', 'Network', 'PMP'],
#  ['Business-Analysis'],
#  ['Python',
#   'SQL',
#   'R',
#   'AWS',
#   'Excel',
#   'Data-Science',
#   'Business-Intelligence',
#   'S3'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'Oracle',
#   'JavaScript',
#   'MySQL',
#   'Power-BI',
#   'CSS'],
#  ['SQL', 'R', 'Tableau', 'Azure', 'Excel', 'Marketing', 'Alteryx'],
#  ['SQL', 'R', 'Tableau', 'Marketing', 'SaaS'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['R',
#   'Tableau',
#   'Excel',
#   'Perl',
#   'Business-Intelligence',
#   'Data-Management',
#   'Epic',
#   'Managed-Care'],
#  ['R',
#   'Tableau',
#   'Excel',
#   'Perl',
#   'Business-Intelligence',
#   'Data-Management',
#   'Epic',
#   'Managed-Care'],
#  ['SQL', 'R', 'SAS', 'AI', 'Excel', 'Marketing', 'Go'],
#  ['Python', 'SQL', 'AI', 'Excel', 'Data-Science', 'Biostatistics'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Microsoft-Office', 'Excel', 'SharePoint'],
#  ['Python', 'SQL', 'R', 'Tableau', 'AI'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['Python', 'SQL', 'R', 'Tableau'],
#  ['Python', 'SQL', 'R', 'Go', 'Google-Analytics'],
#  ['R', 'Tableau', 'Microsoft-Office', 'Excel', 'CI'],
#  ['R', 'Excel'],
#  ['SQL', 'R', 'Oracle', 'Teradata', 'DB2'],
#  ['SQL', 'R', 'Tableau', 'AWS', 'Business-Intelligence'],
#  ['R', 'Excel'],
#  ['SQL', 'R', 'Excel', 'Go'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel', 'Go', 'Google-Analytics'],
#  ['R', 'Excel', 'Business-Intelligence', 'Go'],
#  ['R', 'Excel', 'Accounting', 'UI', 'RN'],
#  ['R', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'AI', 'Excel', 'SAP', 'Go'],
#  ['SQL', 'R', 'SAS', 'Clinical-Trials', 'IDS'],
#  ['R', 'Excel', 'Accounting'],
#  ['SQL', 'Tableau', 'Business-Intelligence'],
#  ['R', 'Excel', 'Accounting', 'UI', 'RN'],
#  ['R', 'Excel'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel', 'Power-BI'],
#  ['Python', 'SQL', 'R', 'Excel', 'Visio', 'GIS'],
#  ['R', 'Big-Data', 'AI', 'Business-Intelligence', 'Go'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Data-Science', 'Alteryx'],
#  ['Python', 'SQL', 'R', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'Microsoft-Office', 'Excel', 'Marketing', 'Marketo'],
#  ['SQL', 'R', 'Excel', 'Network', 'Visio', 'Epic', 'UI', 'ACH'],
#  ['SQL', 'R', 'AI'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Excel', 'ICD-9'],
#  ['SQL', 'SAS', 'Accounting', 'Business-Management'],
#  ['R', 'Microsoft-Office', 'Excel', 'Go'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Microsoft-Office',
#   'Excel',
#   'Marketing',
#   'T-SQL',
#   'Quality-Management',
#   'Biostatistics'],
#  ['SQL',
#   'R',
#   'Java',
#   'Excel',
#   'JavaScript',
#   'Business-Intelligence',
#   'Go',
#   'Google-Analytics'],
#  ['R', 'Tableau', 'Excel', 'Visio', 'Accounting'],
#  ['SQL', 'R', 'SAS', 'Excel'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel', 'Ruby'],
#  ['R', 'Tableau', 'Excel', 'Power-BI', 'Accounting'],
#  ['SQL', 'R', 'SAS', 'Microsoft-Office', 'Excel', 'SPSS', 'STATA'],
#  ['R', 'Excel'],
#  ['R', 'AI'],
#  ['R', 'Microsoft-Office', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Excel',
#   'Project-Management',
#   'Marketing',
#   'Business-Management'],
#  ['SQL', 'R', 'Data-Science'],
#  ['R', 'Excel', 'Marketing', 'Network', 'Go', 'Omniture'],
#  ['R', 'Tableau', 'Excel', 'Project-Management', 'Management-Experience'],
#  ['R', 'Excel'],
#  ['R', 'Git', 'Excel', 'Go'],
#  ['R',
#   'Oracle',
#   'Excel',
#   'Business-Analysis',
#   'Go',
#   'System-Design',
#   'PMP',
#   'CPA',
#   'Oracle-EBS'],
#  ['R',
#   'Microsoft-Office',
#   'Excel',
#   'Power-BI',
#   'Marketing',
#   'Go',
#   'Google-Suite'],
#  ['R'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'AWS',
#   'Excel',
#   'Data-Science',
#   'Marketing',
#   'Alteryx'],
#  ['SQL', 'R', 'Data-Science', 'Business-Intelligence', 'UI'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Oracle',
#   'Microsoft-SQL-Server',
#   'Excel',
#   'MySQL',
#   'Business-Intelligence',
#   'Power-BI',
#   'Go',
#   'Google-Analytics'],
#  ['SQL',
#   'R',
#   'Java',
#   'Oracle',
#   'Git',
#   'Excel',
#   'JavaScript',
#   'S3',
#   'Teradata',
#   'REST',
#   'XML',
#   'HTML5',
#   'DB2',
#   'CSS',
#   'Angular',
#   'React',
#   'SOAP',
#   'UI',
#   'Tomcat'],
#  ['SQL',
#   'R',
#   'Excel',
#   'Project-Management',
#   'Jira',
#   'Visio',
#   'Confluence',
#   'SOX'],
#  ['SQL', 'R', 'Excel', 'Marketo'],
#  ['SDLC', 'Go', 'UI', 'UX'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'AI',
#   'Excel',
#   'Marketing',
#   'Go',
#   'Google-Analytics',
#   'Digital-Marketing',
#   'Omniture'],
#  ['SQL', 'Tableau', 'Data-Science', 'Go', 'UX'],
#  ['R', 'Excel', 'Perl', 'Epic'],
#  ['Python', 'SQL', 'Microsoft-Office', 'Excel', 'Business-Intelligence'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Business-Intelligence', 'Network'],
#  ['R', 'Excel', 'UI', 'Customer-Service'],
#  ['SQL', 'R', 'Excel', 'Accounting'],
#  ['Python', 'R', 'Excel', 'Data-Management', 'Quantitative-Analysis'],
#  ['Python', 'SQL', 'R', 'Java', 'Tableau', 'Excel', 'Ruby', 'Power-BI'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Oracle',
#   'Linux',
#   'Microsoft-Office',
#   'Excel',
#   'Business-Intelligence',
#   'Marketing',
#   'Go',
#   'Google-Analytics',
#   'Omniture'],
#  ['Python', 'SQL', 'R', 'Java', 'Tableau', 'Power-BI'],
#  ['R', 'Excel', 'Marketing', 'Visio'],
#  ['R',
#   'Project-Management',
#   'Jira',
#   'Go',
#   'Software-Testing',
#   'Process-Engineering'],
#  ['R', 'Excel', 'UI'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['R', 'Oracle', 'Excel', 'Marketing', 'SAP', 'Customer-Service'],
#  ['R', 'Tableau', 'Excel', 'Marketing'],
#  ['Python', 'R', 'Tableau', 'Excel', 'Marketing'],
#  ['SQL', 'R', 'Excel', 'Business-Intelligence', 'UI'],
#  ['SQL', 'R', 'Hadoop', 'Tableau', 'Hive', 'Excel'],
#  ['R', 'Tableau', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'Oracle',
#   'Excel',
#   'JavaScript',
#   'Marketing',
#   'SAP',
#   'Digital-Marketing'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Microsoft-Office',
#   'Excel',
#   'Business-Intelligence',
#   'CI',
#   'Go'],
#  ['R', 'Excel', 'SaaS'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Visio'],
#  ['R',
#   'Excel',
#   'Marketing',
#   'Go',
#   'Google-Analytics',
#   'Google-Search-Console',
#   'SEO'],
#  ['R'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Data-Warehouse',
#   'Business-Intelligence',
#   'Power-BI'],
#  ['R', 'Marketing'],
#  ['SQL', 'R', 'Tableau', 'Oracle', 'Excel', 'Marketing', 'UI'],
#  ['R', 'Excel', 'Windows'],
#  ['SQL', 'R', 'Data-Analysis', 'Excel'],
#  ['Python', 'SQL', 'R'],
#  ['R', 'Go'],
#  ['R', 'Microsoft-Office', 'Excel', 'Go'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Omniture'],
#  ['Tableau', 'Excel', 'Business-Intelligence'],
#  ['R', 'Excel', 'CI', 'Go'],
#  ['Excel', 'Business-Analysis'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Business-Intelligence'],
#  ['R', 'Oracle', 'Excel', 'Perl', 'CI', 'PeopleSoft'],
#  ['R', 'Excel', 'Go'],
#  ['R', 'Tableau', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['SQL',
#   'R',
#   'Oracle',
#   'Excel',
#   'Data-Science',
#   'Business-Intelligence',
#   'Microsoft-Access',
#   'Business-Analysis',
#   'Customer-Service'],
#  ['SQL', 'R', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'Git',
#   'JSON',
#   'Alteryx',
#   'PL/SQL',
#   'React'],
#  ['R', 'Data-Analysis', 'Excel', 'Accounting'],
#  ['R', 'Excel', 'Accounting'],
#  ['R',
#   'Java',
#   'JavaScript',
#   'JSON',
#   'XML',
#   'Analysis-Skills',
#   'Go',
#   'CSS',
#   'UI',
#   'UX',
#   'Drupal',
#   'Magento',
#   'WordPress',
#   'Conflict-Management'],
#  ['R', 'Excel'],
#  ['R', 'Excel', 'Visio', 'CI'],
#  ['R'],
#  ['R', 'AI', 'Excel'],
#  ['R', 'Excel', 'Marketing', 'Visio', 'Epic', 'Epic-Certification', 'RN'],
#  ['R'],
#  ['R', 'Epidemiology', 'Biostatistics'],
#  ['R', 'Marketing', 'SAP', 'Epic', 'Epic-Certification'],
#  ['R', 'Excel', 'SDLC', 'UI'],
#  ['R', 'Excel', 'SDLC', 'UI'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Excel',
#   'Power-BI',
#   'Business-Management'],
#  ['R', 'Excel', 'Marketing', 'Visio', 'CI'],
#  ['R', 'Excel'],
#  ['R', 'Excel', 'SDLC', 'Jira', 'Visio', 'UI'],
#  ['Python', 'SQL', 'Microsoft-Office', 'Excel', 'Business-Intelligence'],
#  ['R', 'Excel', 'SAP', 'Network', 'Accounting'],
#  ['R', 'Excel', 'Power-BI'],
#  ['R', 'Excel', 'Marketing', 'CI'],
#  ['R'],
#  ['R', 'Excel', 'Software-Development', 'Visio', 'CI', 'Go', 'UI'],
#  ['R', 'PMP'],
#  ['SQL', 'R', 'Excel', 'Software-Development', 'SDLC', 'Business-Analysis'],
#  ['R', 'Excel'],
#  ['R', 'Excel', 'SAP', 'SOX'],
#  ['SQL', 'R', 'Go', 'Accounting'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Go',
#   'Hyperion',
#   'Google-Suite'],
#  ['R', 'Excel'],
#  ['R', 'PMP'],
#  ['R', 'Excel'],
#  ['R', 'Data-Management'],
#  ['Python', 'SQL', 'Java', 'C/C++', 'Excel'],
#  ['R'],
#  ['R', 'Accounting'],
#  ['SQL', 'R', 'SAS', 'Excel', 'XML', 'Workday', 'FTP'],
#  ['SQL', 'R', 'Data-Warehouse', 'Excel'],
#  ['R', 'Marketing', 'Network', 'Go', 'Customer-Service', 'Managed-Care'],
#  ['R', 'AI', 'UI'],
#  ['Python', 'R', 'Excel'],
#  ['SQL', 'R', 'Excel'],
#  ['R', 'Excel', 'Marketing', 'Visio', 'CI', 'RN'],
#  ['R', 'Excel'],
#  ['Python', 'R', 'Git', 'Data-Science'],
#  ['R', 'Microsoft-Office', 'Excel', 'Accounting'],
#  ['R', 'Tableau', 'Excel', 'SDLC'],
#  ['R', 'Excel', 'SAP', 'Network', 'Accounting'],
#  ['R', 'Excel', 'Accounting', 'RN'],
#  ['Python', 'SQL', 'R', 'PostgreSQL', 'MongoDB'],
#  ['R', 'Excel', 'Data-Management'],
#  ['R', 'Data-Management', 'Accounting', 'Regulatory-Reporting', 'IFRS'],
#  ['R', 'Data-Science'],
#  ['Python', 'SQL', 'R', 'SAS', 'AI', 'Excel', 'XML', 'IDS'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Oracle', 'Excel', 'MySQL', 'Go', 'SEO'],
#  ['R', 'Excel', 'Go'],
#  ['R', 'Marketing', 'Network', 'Go', 'Customer-Service', 'Managed-Care'],
#  ['R', 'Power-BI'],
#  ['SQL', 'R', 'Tableau', 'Excel'],
#  ['R',
#   'Excel',
#   'CI',
#   'Accounting',
#   'Customer-Service',
#   'Financial-Accounting',
#   'Payroll'],
#  ['Python', 'R'],
#  ['Python', 'R'],
#  ['R'],
#  ['SQL', 'R', 'SAS', 'Biostatistics'],
#  ['R', 'SAS', 'Epidemiology', 'Biostatistics'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'Linux',
#   'Perl',
#   'Teradata',
#   'Windows'],
#  ['Python', 'SQL', 'R', 'Java', 'JavaScript', 'Google-Cloud-Platform', 'Go'],
#  ['R'],
#  ['R', 'Excel'],
#  ['Python', 'R', 'Java', 'Tableau', 'Excel', 'JavaScript'],
#  ['Python', 'SQL', 'R', 'Oracle', 'Excel', 'JSON', 'XML', 'Go'],
#  ['R', 'Marketing'],
#  ['R', 'Excel'],
#  ['Python', 'SQL', 'R', 'NoSQL', 'ICD-10'],
#  ['R'],
#  ['R'],
#  ['Python', 'SQL', 'R', 'Excel', 'GIS', 'Accounting'],
#  ['SQL', 'R', 'SAS', 'AI', 'Excel', 'SPSS', 'Operations-Research'],
#  ['R', 'Microsoft-Office', 'Excel'],
#  ['SQL', 'R', 'SAS', 'Excel', 'SPSS', 'UI'],
#  ['SQL', 'R', 'SAS', 'Excel', 'CI'],
#  ['SQL', 'R', 'Tableau', 'Microsoft-Office', 'Excel'],
#  ['R', 'SAS', 'AI', 'Excel', 'Epidemiology', 'IDS'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'SAS',
#   'Excel',
#   'Visual-Basic',
#   'Operations-Research'],
#  ['R', 'Excel', 'UI'],
#  ['Python', 'SQL', 'R', 'Excel', 'GIS'],
#  ['R', 'Excel', 'Go'],
#  ['SQL', 'R', 'Tableau', 'Marketing', 'Visio', 'Go'],
#  ['R', 'Microsoft-Office', 'Excel'],
#  ['Python', 'Data-Analysis', 'Excel'],
#  ['Python', 'R', 'AI', 'TensorFlow', 'Data-Science', 'CI', 'Workday', 'RN'],
#  ['R', 'Excel'],
#  ['R', 'Excel', 'Data-Management', 'CI'],
#  ['R',
#   'Spark',
#   'Microsoft-Office',
#   'Excel',
#   'Marketing',
#   'Data-Management',
#   'CI',
#   'Digital-Marketing',
#   'CPA'],
#  ['SQL', 'Oracle', 'Business-Analysis'],
#  ['R', 'Big-Data'],
#  ['SQL', 'R', 'SAS', 'Excel', 'ICD-10', 'ICD-9'],
#  ['R', 'Data-Management', 'Go'],
#  ['Python',
#   'SQL',
#   'R',
#   'Microsoft-Office',
#   'Excel',
#   'Project-Management',
#   'Quality-Management'],
#  ['SQL', 'R', 'Tableau', 'AWS', 'Excel', 'CI', 'Unity'],
#  ['R'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'SPSS',
#   'Data-Science',
#   'Business-Intelligence',
#   'Power-BI',
#   'Marketing'],
#  ['R', 'Git', 'Excel', 'Go'],
#  ['SQL', 'R', 'Data-Warehouse', 'Excel', 'JSON'],
#  ['R', 'Microsoft-Office', 'Excel'],
#  ['Python', 'SQL', 'R', 'AI', 'Excel', 'Workday', 'RN'],
#  ['R', 'Tableau', 'Excel', 'Six-Sigma'],
#  ['R', 'SAS', 'Excel', 'Biostatistics'],
#  ['R'],
#  ['Python', 'R', 'Java', 'Tableau', 'Excel', 'JavaScript'],
#  ['R', 'Microsoft-Office', 'Excel', 'SAP', 'CI', 'Payroll'],
#  ['SQL', 'R', 'Excel', 'Go'],
#  ['R', 'RN'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel', 'Data-Science'],
#  ['Python', 'SQL', 'R', 'Excel', 'Informatica'],
#  ['Python', 'SQL', 'R', 'Microsoft-Office', 'Excel'],
#  ['SQL', 'SAS', 'Excel'],
#  ['Python', 'SQL', 'R', 'Excel'],
#  ['Python', 'SQL', 'R', 'Hadoop', 'Tableau', 'Excel'],
#  ['R', 'Tableau', 'Excel', 'Data-Management', 'Workday'],
#  ['Python', 'SQL', 'R', 'Tableau', 'SAS', 'Excel', 'Go', 'Clinical-Research'],
#  ['SQL', 'R', 'Excel', 'Go', 'FTP'],
#  ['R'],
#  ['R', 'Data-Science', 'Business-Intelligence', 'Epic'],
#  ['R', 'Network', 'UI'],
#  ['Python', 'SQL', 'R', 'Excel', 'Visio', 'Audits'],
#  ['R', 'SAS', 'MATLAB'],
#  ['R',
#   'Tableau',
#   'Excel',
#   'Marketing',
#   'Data-Management',
#   'Network',
#   'Go',
#   'Google-Analytics',
#   'FTP',
#   'Marketo',
#   'SEO'],
#  ['R', 'Marketing'],
#  ['R',
#   'Tableau',
#   'Data-Science',
#   'Business-Intelligence',
#   'Power-BI',
#   'Marketing',
#   'Go',
#   'Google-Analytics',
#   'Public-Relations'],
#  ['R', 'Excel', 'SDLC', 'Business-Analysis', 'CI', 'Go', 'Troubleshooting'],
#  ['R', 'Excel', 'Marketing', 'Pardot'],
#  ['R', 'Data-Management', 'Go', 'Accounting', 'Regulatory-Reporting'],
#  ['R', 'SAS', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Power-BI'],
#  ['R', 'Excel'],
#  ['Python',
#   'R',
#   'Java',
#   'Excel',
#   'Perl',
#   'Project-Management',
#   'C',
#   '#',
#   'PHP',
#   'Business-Analysis',
#   'Go',
#   'Application-Support'],
#  ['R', 'Excel', 'Marketing', 'Go', 'Google-Analytics'],
#  ['R', 'Excel', 'Perl', 'Epic'],
#  ['R'],
#  ['R'],
#  ['R', 'Excel', 'Microsoft-Word'],
#  ['R', 'Excel'],
#  ['Python', 'SQL', 'R', 'Java', 'Excel', 'C', '#'],
#  ['SQL'],
#  ['R', 'Microsoft-Office'],
#  ['R', 'Excel'],
#  ['R', 'Excel', 'Perl', 'Epic'],
#  ['R', 'AI', 'Excel'],
#  ['Python', 'SQL', 'R', 'Tableau', 'SAS', 'Excel', 'Visual-Basic'],
#  ['R', 'Tableau', 'SAS', 'Microsoft-Office', 'Excel', 'SPSS', 'GIS'],
#  ['R', 'Excel', 'Perl', 'Epic'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['R', 'Tableau', 'SAS', 'Excel', 'SPSS', 'Audits', 'UI'],
#  ['R'],
#  ['R', 'Excel', 'Microsoft-Access'],
#  ['Python', 'SQL', 'R', 'Excel', 'GIS'],
#  ['R', 'Excel'],
#  ['SQL', 'R', 'SAS', 'Excel', 'Network', 'Maven'],
#  ['R', 'Excel', 'STATA'],
#  ['SQL', 'R', 'SAS', 'Excel'],
#  ['R', 'Excel', 'Perl', 'Epic'],
#  ['Python',
#   'SQL',
#   'R',
#   'Microsoft-SQL-Server',
#   'Excel',
#   'C',
#   '#',
#   'Microsoft-Access',
#   'SharePoint'],
#  ['R', 'Excel', 'Perl', 'Epic'],
#  ['Python', 'SQL', 'Excel'],
#  ['R', 'Excel', 'Go'],
#  ['Python', 'SQL', 'R', 'Tableau', 'AWS'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Excel', 'SPSS'],
#  ['R', 'Microsoft-Office', 'Excel', 'Go'],
#  ['R', 'Microsoft-Office', 'Excel', 'Power-BI', 'Go', 'Google-Analytics'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Oracle',
#   'Data-Warehouse',
#   'Microsoft-SQL-Server',
#   'Scripting',
#   'Crystal-Reports',
#   'Epic'],
#  ['R', 'Tableau', 'SAS', 'Microsoft-Office', 'Excel', 'SPSS', 'GIS'],
#  ['R', 'AI', 'Data-Analysis'],
#  ['SQL', 'R', 'Tableau', 'Oracle', 'Data-Science'],
#  ['R'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Oracle',
#   'Excel',
#   'Teradata',
#   'Marketing',
#   'Data-Management',
#   'Visio'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Power-BI'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Oracle',
#   'Excel',
#   'SPSS',
#   'Business-Intelligence',
#   'Power-BI',
#   'STATA',
#   'GIS',
#   'Telecommunication'],
#  ['R', 'Excel'],
#  ['R', 'Excel'],
#  ['SQL', 'R', 'Tableau'],
#  ['R', 'Microsoft-Office', 'Excel', 'Go', 'ACH'],
#  ['Python', 'SQL', 'R', 'Spark', 'SAS', 'AWS', 'S3', 'Visio'],
#  ['R'],
#  ['Python', 'R', 'Hadoop', 'Tableau', 'Go'],
#  ['Python', 'Hadoop', 'Tableau', 'Go'],
#  ['R', 'Excel', 'SDLC', 'Business-Analysis', 'CI', 'Go', 'Troubleshooting'],
#  ['Python', 'SQL', 'R', 'AWS', 'Data-Science'],
#  ['R', 'Excel', 'Accounting'],
#  ['Machine-Learning',
#   'R',
#   'Big-Data',
#   'AI',
#   'Data-Analysis',
#   'MATLAB',
#   'Excel',
#   'S3',
#   'Network',
#   'Go',
#   'UI',
#   'SSL'],
#  ['Python', 'R', 'SAS', 'Scala', 'Go', 'Bioinformatics', 'Genetics'],
#  ['R', 'Data-Management', 'SAP', 'Process-Management', 'Business-Management'],
#  ['R', 'Tableau', 'Excel', 'Go', 'Google-Analytics'],
#  ['R', 'Microsoft-Office', 'Excel', 'Data-Management', 'Accounting'],
#  ['R', 'AI', 'Excel', 'Marketing'],
#  ['SQL',
#   'Machine-Learning',
#   'R',
#   'SAS',
#   'Data-Warehouse',
#   'AI',
#   'Excel',
#   'Power-BI'],
#  ['Python', 'R', 'SAS', 'Scripting', 'Go', 'Android'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'SAS',
#   'Scala',
#   'Perl',
#   'SPSS',
#   'Network',
#   'Go'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'Marketing',
#   'Go',
#   'Google-Analytics',
#   'Omniture'],
#  ['SQL', 'R', 'Excel', 'Go', 'Ant'],
#  ['Python',
#   'SQL',
#   'R',
#   'Spark',
#   'Java',
#   'Tableau',
#   'Big-Data',
#   'AWS',
#   'Scala',
#   'NoSQL',
#   'Oracle',
#   'Azure',
#   'MySQL',
#   'Data-Science',
#   'S3',
#   'Google-Cloud-Platform',
#   'Jira',
#   'Apache',
#   'Go',
#   'Confluence'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'SAS',
#   'Excel',
#   'Data-Science',
#   'Statistical-Software',
#   'Alteryx',
#   'QlikView',
#   'DB2',
#   'Go',
#   'Operations-Research'],
#  ['Python', 'SQL', 'R', 'Tableau'],
#  ['Python', 'SQL', 'R', 'Tableau', 'AWS', 'Operations-Research'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Big-Data',
#   'Excel',
#   'Data-Science',
#   'Customer-Segmentation'],
#  ['Python', 'SQL', 'R', 'Git', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'AWS',
#   'AI',
#   'Data-Science',
#   'Go',
#   'Google-Analytics',
#   'SaaS'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Excel',
#   'Business-Intelligence',
#   'STATA',
#   'Epidemiology',
#   'Ant',
#   'Biostatistics'],
#  ['R', 'Excel', 'Data-Science', 'Business-Intelligence'],
#  ['SQL', 'R', 'Java', 'JavaScript', 'Business-Intelligence'],
#  ['Excel', 'Network', 'Go', 'UI'],
#  ['R'],
#  ['Python', 'SQL', 'R', 'Data-Science'],
#  ['R', 'Project-Management', 'SDLC', 'Business-Analysis', 'Go'],
#  ['SQL', 'R', 'SAS', 'Accounting', 'Epic', 'UI'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'Data-Warehouse',
#   'Excel',
#   'Informatica',
#   'Alteryx'],
#  ['R', 'Excel'],
#  ['R',
#   'Tableau',
#   'Data-Analysis',
#   'Excel',
#   'Marketing',
#   'Data-Management',
#   'SAP'],
#  ['SQL', 'R', 'PowerShell', 'Windows'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Business-Intelligence', 'QlikView'],
#  ['Python', 'SQL', 'Microsoft-Office', 'Excel', 'Business-Intelligence'],
#  ['SQL',
#   'R',
#   'Data-Warehouse',
#   'Excel',
#   'Project-Management',
#   'Business-Intelligence',
#   'Business-Analysis',
#   'Go',
#   'PMP'],
#  ['SQL', 'R', 'Tableau', 'NoSQL', 'Excel', 'Marketing'],
#  ['R', 'Excel', 'CI', 'Go', 'Telecommunication', 'IAT', 'ACH'],
#  ['SQL', 'R', 'Data-Analysis'],
#  ['R', 'Excel', 'Marketing'],
#  ['R', 'Excel', 'SDLC', 'Visio'],
#  ['Tableau', 'Excel', 'Go', 'Google-Analytics'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Microsoft-Office',
#   'Excel',
#   'Business-Intelligence',
#   'Google-Cloud-Platform',
#   'Go',
#   'Confluence',
#   'Google-Analytics',
#   'Omniture',
#   'Doubleclick',
#   'iOS',
#   'Android'],
#  ['R'],
#  ['SQL', 'R', 'AI', 'Microsoft-Office', 'Excel'],
#  ['R', 'SAS', 'Excel', 'Microsoft-Access', 'Network'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'AWS',
#   'Azure',
#   'HBase',
#   'MongoDB',
#   'Ruby',
#   'Elasticsearch',
#   'REST',
#   'Jenkins',
#   'Solr',
#   'Angular',
#   'Maven',
#   'Ansible',
#   'Redis',
#   'Lucene',
#   'Spring',
#   'Bootstrap',
#   'SSL'],
#  ['SQL', 'R', 'SAS', 'Excel'],
#  ['R', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'AWS',
#   'Excel',
#   'Marketing',
#   'Marketing-Mix-Modeling'],
#  ['SQL',
#   'R',
#   'Oracle',
#   'Excel',
#   'SAP',
#   'Go',
#   'Crystal-Reports',
#   'Accounting',
#   'Payroll'],
#  ['R', 'Excel'],
#  ['R'],
#  ['Python', 'R', 'Java', 'Tableau', 'JavaScript', 'CSS', 'UI'],
#  ['R'],
#  ['R'],
#  ['SQL', 'R', 'Java', 'Excel', 'Project-Management', 'SDLC', 'Go'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Excel', 'Ruby'],
#  ['Python',
#   'SQL',
#   'Machine-Learning',
#   'R',
#   'Spark',
#   'SAS',
#   'Scala',
#   'MATLAB',
#   'Data-Science',
#   'STATA'],
#  ['R', 'Excel', 'Microsoft-Word', 'Accounting'],
#  ['Python', 'R', 'Marketing'],
#  ['R', 'Excel', 'STATA'],
#  ['Python', 'SQL', 'R', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Excel',
#   'SPSS',
#   'Business-Intelligence',
#   'JSON',
#   'Go',
#   'UI'],
#  ['Python',
#   'SQL',
#   'R',
#   'Azure',
#   'Excel',
#   'Data-Science',
#   'Marketing',
#   'Visio',
#   'Go',
#   'Adobe-Marketing'],
#  ['R', 'Excel'],
#  ['R', 'Marketing', 'Adobe-Marketing'],
#  ['R', 'Excel'],
#  ['R', 'Excel', 'Visio', 'CI', 'Microsoft-Word', 'Process-Improvement'],
#  ['SQL',
#   'R',
#   'SAS',
#   'Oracle',
#   'Excel',
#   'Business-Intelligence',
#   'CI',
#   'CSS',
#   'Managed-Care',
#   'Regulatory-Reporting'],
#  ['R',
#   'Tableau',
#   'Excel',
#   'Power-BI',
#   'Alteryx',
#   'CI',
#   'Accounting',
#   'CPA',
#   'CFE'],
#  ['Excel', 'SDLC'],
#  ['SQL', 'R', 'Data-Analysis', 'Excel', 'Visio'],
#  ['R',
#   'Java',
#   'Tableau',
#   'Oracle',
#   'AI',
#   'Business-Intelligence',
#   'Informatica',
#   'Teradata',
#   'Data-Management',
#   'HTML5',
#   'Go',
#   'CSS'],
#  ['R', 'Excel', 'Perl', 'Epic'],
#  ['SQL',
#   'R',
#   'Excel',
#   'Power-BI',
#   'Marketing',
#   'Go',
#   'Accounting',
#   'PeopleSoft',
#   'Managed-Care',
#   'GAAP'],
#  ['R', 'Excel', 'SDLC', 'Visio'],
#  ['SQL', 'R', 'AI', 'UI'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Excel',
#   'Perl',
#   'Software-Development',
#   'C',
#   '#',
#   'DB2',
#   'Sybase'],
#  ['R', 'Excel', 'SaaS'],
#  ['Python', 'SQL', 'R', 'Data-Science'],
#  ['R',
#   'Spark',
#   'Microsoft-Office',
#   'Excel',
#   'Marketing',
#   'Data-Management',
#   'CI',
#   'Digital-Marketing',
#   'UI',
#   'CPA'],
#  ['R', 'Excel', 'Accounting'],
#  ['R', 'Tableau', 'Excel', 'Go', 'ITIL'],
#  ['R', 'CI'],
#  ['R', 'Excel', 'SAP', 'Network'],
#  ['SQL', 'R', 'Excel', 'SPSS', 'Power-BI', 'Visio'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Oracle',
#   'AI',
#   'Excel',
#   'PostgreSQL',
#   'MySQL',
#   'Crystal-Reports',
#   'Epic',
#   'Quality-Management',
#   'Cerner',
#   'IDS'],
#  ['R', 'Microsoft-Office', 'Excel'],
#  ['Machine-Learning', 'R', 'Data-Science'],
#  ['SQL', 'R', 'Project-Management', 'Business-Analysis'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Oracle',
#   'Microsoft-SQL-Server',
#   'Excel',
#   'MySQL',
#   'Business-Intelligence',
#   'Power-BI',
#   'Go',
#   'Google-Analytics'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Git',
#   'Excel',
#   'JavaScript',
#   'Data-Science',
#   'Splunk',
#   'XML',
#   'PHP',
#   'HTML5',
#   'Go',
#   'CSS',
#   'Google-Analytics',
#   'Omniture',
#   'Google-Search-Console',
#   'SEO'],
#  ['Python',
#   'SQL',
#   'R',
#   'Hadoop',
#   'Tableau',
#   'SAS',
#   'SPSS',
#   'Business-Intelligence'],
#  ['R', 'Excel', 'CI', 'Go', 'IAT', 'ACH'],
#  ['R', 'Visio', 'FTP', 'Windows'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Excel'],
#  ['SQL', 'R', 'Oracle', 'AI', 'Excel', 'PL/SQL', 'PeopleSoft'],
#  ['SQL', 'R', 'SAS', 'Clinical-Trials', 'IDS'],
#  ['R'],
#  ['R', 'Accounting', 'Business-Management'],
#  ['R', 'Excel', 'Accounting', 'UI'],
#  ['Python', 'SQL', 'R', 'Excel', 'Data-Management', 'UI'],
#  ['Business-Analysis'],
#  ['R',
#   'Microsoft-Office',
#   'Excel',
#   'Business-Intelligence',
#   'Marketing',
#   'SharePoint'],
#  ['R', 'Business-Analysis', 'Go'],
#  ['SQL', 'Excel'],
#  ['R', 'Business-Analysis', 'Visio'],
#  ['R', 'Excel'],
#  ['SQL',
#   'R',
#   'Data-Warehouse',
#   'Excel',
#   'Project-Management',
#   'Data-Management',
#   'Business-Analysis',
#   'Accounting'],
#  ['Python', 'SQL', 'R', 'C/C++', 'AI', 'Excel', 'Go'],
#  ['R'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Data-Science',
#   'Business-Intelligence',
#   'Marketing',
#   'Business-Analysis',
#   'CI'],
#  ['R', 'Oracle', 'Excel', 'Go', 'Salesforce-CRM'],
#  ['R'],
#  ['R',
#   'Data-Analysis',
#   'Excel',
#   'Project-Management',
#   'Business-Analysis',
#   'Microsoft-Project'],
#  ['Python',
#   'SQL',
#   'Machine-Learning',
#   'R',
#   'Tableau',
#   'AWS',
#   'AI',
#   'Excel',
#   'Data-Science',
#   'Business-Intelligence',
#   'Informatica',
#   'Marketing',
#   'Alteryx',
#   'Network',
#   'Go',
#   'Google-Analytics',
#   'Digital-Marketing'],
#  ['R', 'Excel', 'Project-Management', 'Visio', 'Adobe-Creative-Suite'],
#  ['Python', 'SQL', 'R', 'Linux', 'Excel', 'Microsoft-Access', 'Windows'],
#  ['R', 'Excel', 'Microsoft-Word'],
#  ['R'],
#  ['R'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Excel', 'Marketing'],
#  ['R', 'Excel', 'Business-Intelligence'],
#  ['R', 'Tableau', 'Go', 'Google-Analytics'],
#  ['R', 'Excel', 'Accounting'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Power-BI',
#   'Go',
#   'PeopleSoft'],
#  ['Python', 'SQL', 'Microsoft-Office', 'Excel', 'Business-Intelligence'],
#  ['R', 'Excel', 'UX'],
#  ['Python',
#   'SQL',
#   'R',
#   'Hadoop',
#   'Spark',
#   'Tableau',
#   'Hive',
#   'NoSQL',
#   'Kafka',
#   'Excel',
#   'Business-Intelligence',
#   'Elasticsearch',
#   'Marketing',
#   'Apache',
#   'Go',
#   'Google-Analytics',
#   'SaaS'],
#  ['R', 'Excel', 'Jira', 'Go', 'Google-Analytics', 'Drupal'],
#  ['R', 'Microsoft-Office', 'Excel', 'Jira', 'Network', 'Visio', 'Go'],
#  ['R', 'Tableau', 'Azure', 'Excel', 'Power-BI', 'Teradata'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Business-Intelligence'],
#  ['R', 'Excel', 'Microsoft-Word', 'PeopleSoft'],
#  ['R',
#   'Excel',
#   'Project-Management',
#   'Business-Intelligence',
#   'Business-Analysis'],
#  ['R', 'Marketing'],
#  ['R', 'Perl', 'Jira', 'Selenium', 'LDAP'],
#  ['R',
#   'Excel',
#   'Data-Science',
#   'Data-Management',
#   'QlikView',
#   'Go',
#   'Microsoft-Word',
#   'Information-Security'],
#  ['Python', 'SQL', 'R', 'Spark', 'SAS', 'AWS', 'S3', 'Visio'],
#  ['R'],
#  ['R', 'Tableau', 'Microsoft-Office', 'Excel', 'SPSS', 'UI'],
#  ['R', 'Excel', 'Project-Management', 'Visio', 'PMP'],
#  ['SQL',
#   'R',
#   'SAS',
#   'Oracle',
#   'Excel',
#   'Business-Intelligence',
#   'CI',
#   'Audits',
#   'Managed-Care',
#   'Regulatory-Reporting'],
#  ['R', 'Excel', 'Go', 'ACH'],
#  ['R', 'Visual-Basic', 'Accounting', 'Hyperion', 'Workday'],
#  ['Python',
#   'R',
#   'SAS',
#   'Scripting',
#   'SPSS',
#   'Data-Science',
#   'Marketing',
#   'Predictive-Analytics',
#   'RN'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Oracle',
#   'AI',
#   'Microsoft-Office',
#   'Excel',
#   'SPSS',
#   'Project-Management',
#   'PeopleSoft',
#   'Program-Management'],
#  ['R',
#   'Oracle',
#   'AI',
#   'Project-Management',
#   'Business-Intelligence',
#   'Marketing',
#   'Data-Management',
#   'Go',
#   'PMP',
#   'VersionOne'],
#  ['R', 'Marketing'],
#  ['SQL', 'R', 'Excel'],
#  ['Excel'],
#  ['R', 'Excel', 'SharePoint'],
#  ['R',
#   'Microsoft-Office',
#   'Excel',
#   'Project-Management',
#   'Hyperion',
#   'Process-Improvement'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Business-Analysis', 'Visio', 'UI'],
#  ['R', 'Excel', 'Go', 'ACH'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Google-Cloud-Platform',
#   'Go',
#   'Accounting'],
#  ['SQL',
#   'R',
#   'Excel',
#   'Project-Management',
#   'Jira',
#   'Visio',
#   'Confluence',
#   'SOX'],
#  ['R', 'AI', 'Excel', 'Go'],
#  ['R', 'Tableau', 'Excel', 'Microsoft-Access', 'Data-Management'],
#  ['R', 'Excel', 'Accounting'],
#  ['R', 'Accounting'],
#  ['SQL', 'R', 'Excel', 'RN'],
#  ['SQL', 'R', 'Excel', 'Visio', 'PMP', 'Windows', 'ICD-9'],
#  ['Python',
#   'SQL',
#   'R',
#   'Hadoop',
#   'Hive',
#   'Marketing',
#   'Quantitative-Research'],
#  ['R', 'Java', 'Oracle', 'Excel'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Data-Warehouse',
#   'Excel',
#   'Project-Management',
#   'Go',
#   'ICD-10'],
#  ['R'],
#  ['R', 'Excel', 'Project-Management'],
#  ['SQL',
#   'R',
#   'Excel',
#   'Power-BI',
#   'Marketing',
#   'Go',
#   'Accounting',
#   'PeopleSoft',
#   'Managed-Care',
#   'GAAP'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['SQL', 'R', 'Excel', 'SPSS', 'Power-BI', 'Visio'],
#  ['R'],
#  ['R', 'Perl', 'Jira', 'Selenium', 'LDAP'],
#  ['R', 'Excel', 'SPSS'],
#  ['R', 'Excel', 'SAP', 'CI', 'Accounting'],
#  ['R', 'Excel', 'E-Commerce'],
#  ['R', 'Excel', 'Crystal-Reports'],
#  ['Python', 'SQL', 'R', 'Java', 'Tableau', 'JavaScript', 'Power-BI'],
#  ['SQL',
#   'R',
#   'Java',
#   'SAS',
#   'Oracle',
#   'Microsoft-Office',
#   'Excel',
#   'Visio',
#   'Accounting',
#   'Ellucian'],
#  ['SQL',
#   'R',
#   'SAS',
#   'Oracle',
#   'Microsoft-SQL-Server',
#   'Excel',
#   'Business-Intelligence',
#   'T-SQL',
#   'PL/SQL',
#   'SharePoint',
#   'UI',
#   'Microsoft-Project'],
#  ['SQL', 'R', 'Java', 'Tableau', 'Excel', 'XML', 'PeopleSoft'],
#  ['R', 'Excel', 'Marketing', 'Visio', 'Epic', 'Epic-Certification', 'RN'],
#  ['R', 'Tableau', 'Power-BI', 'Payroll'],
#  ['R', 'Excel'],
#  ['R', 'Excel', 'Customer-Service', 'Certified-Internal-Auditor'],
#  ['SQL', 'R', 'Oracle', 'Data-Analysis', 'Excel', 'Microsoft-Access'],
#  ['SQL', 'R', 'Tableau'],
#  ['R', 'Excel', 'UI', 'Customer-Service'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Excel', 'Business-Intelligence'],
#  ['SQL', 'R', 'Excel', 'Visio', 'CI', 'SharePoint'],
#  ['SQL', 'R', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'SAS', 'Excel'],
#  ['R',
#   'Oracle',
#   'Excel',
#   'Business-Analysis',
#   'Accounting',
#   'Hyperion',
#   'GAAP',
#   'Business-Management'],
#  ['SQL', 'R', 'Tableau', 'AI', 'Excel', 'SAP'],
#  ['R', 'SAS', 'Excel', 'SPSS'],
#  ['R', 'Excel', 'SharePoint'],
#  ['R',
#   'Microsoft-Office',
#   'Excel',
#   'Marketing',
#   'SAP',
#   'Go',
#   'Google-Analytics'],
#  ['R',
#   'Tableau',
#   'Microsoft-Office',
#   'Excel',
#   'Alteryx',
#   'Visio',
#   'SharePoint',
#   'UI'],
#  ['SQL', 'R', 'Tableau', 'Business-Intelligence', 'QlikView'],
#  ['R', 'Microsoft-Office', 'Management-Consulting'],
#  ['Python',
#   'SQL',
#   'Machine-Learning',
#   'R',
#   'Spark',
#   'SAS',
#   'TensorFlow',
#   'MySQL',
#   'Data-Science',
#   'Go',
#   'Google-Analytics',
#   'Omniture'],
#  ['R', 'Excel'],
#  ['SQL', 'R', 'Visio'],
#  ['R', 'Tableau', 'Oracle', 'Excel', 'Accounting', 'Hyperion'],
#  ['R'],
#  ['Python',
#   'R',
#   'Java',
#   'Linux',
#   'Excel',
#   'Ruby',
#   'Go',
#   'Information-Security'],
#  ['R', 'Accounting', 'Epic', 'UI'],
#  ['R', 'Excel'],
#  ['R', 'Excel', 'Go'],
#  ['R', 'Excel'],
#  ['R',
#   'Oracle',
#   'AI',
#   'Project-Management',
#   'Business-Intelligence',
#   'Marketing',
#   'Data-Management',
#   'Go',
#   'PMP',
#   'VersionOne'],
#  ['R', 'Tableau', 'Excel', 'Business-Intelligence', 'Network'],
#  ['R', 'Excel'],
#  ['R',
#   'Tableau',
#   'Excel',
#   'Go',
#   'Google-Analytics',
#   'Social-Media-Management',
#   'CPA'],
#  ['Python',
#   'R',
#   'Tableau',
#   'Excel',
#   'Power-BI',
#   'Marketing',
#   'Jira',
#   'Go',
#   'Google-Analytics'],
#  ['R', 'Microsoft-Office', 'Accounting'],
#  ['R', 'Excel', 'iOS', 'UX', 'Android'],
#  ['Python', 'R', 'Java', 'Excel', 'SaaS'],
#  ['R', 'Excel', 'Data-Management', 'Telecommunication'],
#  ['Python',
#   'Machine-Learning',
#   'R',
#   'Hadoop',
#   'Spark',
#   'Java',
#   'Big-Data',
#   'Scala',
#   'Azure',
#   'JavaScript',
#   'C',
#   '#',
#   'HTML5',
#   'CSS',
#   'Node.js',
#   'React'],
#  ['R', 'Jira', 'Business-Analysis', 'Visio'],
#  ['SQL', 'R', 'Informatica', 'Go', 'PowerShell', 'UX'],
#  ['R',
#   'Excel',
#   'Marketing',
#   'Go',
#   'Google-Analytics',
#   'Management-Consulting',
#   'Omniture'],
#  ['R'],
#  ['R'],
#  ['Python',
#   'SQL',
#   'R',
#   'Excel',
#   'Data-Science',
#   'Management-Experience',
#   'SaaS'],
#  ['SQL', 'R', 'Business-Intelligence', 'Visio', 'Go'],
#  ['R', 'Marketing'],
#  ['R', 'Oracle', 'Excel'],
#  ['R', 'Excel', 'Go', 'SaaS', 'Lean'],
#  ['SQL', 'R', 'Excel', 'SharePoint', 'Crystal-Reports'],
#  ['R', 'Excel', 'Marketing', 'Go', 'Android'],
#  ['SQL', 'R', 'Excel', 'CI', 'Go', 'ACH'],
#  ['R', 'AI', 'Excel'],
#  ['R', 'Excel', 'Business-Analysis', 'Go'],
#  ['SQL', 'R', 'Tableau', 'Oracle', 'Excel', 'Power-BI', 'UI'],
#  ['R'],
#  ['R', 'AI'],
#  ['R', 'Excel', 'Accounting', 'PeopleSoft'],
#  ['Python',
#   'SQL',
#   'Machine-Learning',
#   'R',
#   'Tableau',
#   'AI',
#   'Data-Analysis',
#   'Excel',
#   'Power-BI',
#   'QlikView',
#   'CI',
#   'Go'],
#  ['R', 'CI'],
#  ['R', 'Marketing'],
#  ['R', 'Excel', 'Regulatory-Reporting'],
#  ['iOS'],
#  ['R'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Google-Cloud-Platform',
#   'Go',
#   'Accounting'],
#  ['R', 'Marketing', 'SAP', 'Epic', 'Epic-Certification'],
#  ['Java', 'Big-Data'],
#  ['R',
#   'Oracle',
#   'Excel',
#   'Business-Analysis',
#   'Accounting',
#   'Hyperion',
#   'GAAP'],
#  ['R', 'Excel', 'Business-Analysis', 'GIS'],
#  ['R', 'Excel', 'Power-BI', 'Visio'],
#  ['SQL',
#   'R',
#   'Data-Analysis',
#   'Microsoft-Office',
#   'Excel',
#   'Software-Development',
#   'SDLC',
#   'Visio'],
#  ['Python', 'SQL', 'Microsoft-Office', 'Excel', 'Business-Intelligence'],
#  ['R', 'Excel', 'SaaS'],
#  ['SQL', 'R', 'Microsoft-Office', 'Excel', 'SDLC', 'Visio', 'SharePoint'],
#  ['R',
#   'Excel',
#   'SDLC',
#   'SAP',
#   'Business-Analysis',
#   'Visio',
#   'Accounting',
#   'PeopleSoft',
#   'Quality-Management',
#   'CPA',
#   'GAAP',
#   'Process-Mapping',
#   'Regulatory-Reporting',
#   'IFRS'],
#  ['Python', 'SQL', 'R', 'Hadoop', 'Hive', 'SAS', 'Data-Science', 'PHP'],
#  ['R', 'Excel', 'Business-Intelligence', 'Time-Management'],
#  ['R', 'Excel', 'Regulatory-Reporting'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Microsoft-Office',
#   'Excel',
#   'Business-Intelligence',
#   'Marketing'],
#  ['R', 'Excel', 'Business-Analysis', 'IaaS'],
#  ['SQL',
#   'Java',
#   'Tableau',
#   'SAS',
#   'Oracle',
#   'Excel',
#   'JavaScript',
#   'MySQL',
#   'Business-Intelligence',
#   'Go',
#   'Google-Analytics',
#   'Omniture'],
#  ['Python',
#   'SQL',
#   'R',
#   'Perl',
#   'Business-Intelligence',
#   'PHP',
#   'Go',
#   'Google-Analytics',
#   'UX'],
#  ['R', 'Excel'],
#  ['R', 'Excel', 'Software-Development', 'Visio'],
#  ['SQL', 'Excel'],
#  ['SQL',
#   'R',
#   'Microsoft-Office',
#   'Excel',
#   'Project-Management',
#   'Visio',
#   'CSS',
#   'RN',
#   'WordPress'],
#  ['Python', 'SQL', 'AI', 'Excel', 'Data-Science', 'Biostatistics'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'SAS',
#   'AI',
#   'JavaScript',
#   'Marketing'],
#  ['R', 'Marketing', 'Go', 'SEO'],
#  ['R', 'Excel', 'Accounting', 'Audits'],
#  ['SQL', 'R', 'Tableau', 'AI', 'Excel', 'SAP', 'Go'],
#  ['R', 'SAP'],
#  ['SQL', 'R', 'Excel', 'Software-Development', 'SDLC', 'Visio'],
#  ['Python', 'SQL', 'R'],
#  ['R', 'SDLC', 'Network', 'Go'],
#  ['R'],
#  ['SQL', 'R', '.Net', 'C', '#', 'Jira', 'Confluence'],
#  ['R', 'Excel', 'Project-Management', 'CI', 'SharePoint'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Data-Warehouse',
#   'Excel',
#   'Project-Management',
#   'Business-Intelligence',
#   'Business-Analysis',
#   'Network',
#   'Go',
#   'Application-Support',
#   'RN'],
#  ['R', 'Excel'],
#  ['R', 'Azure', 'Business-Analysis', 'Visio', 'SaaS', 'UI'],
#  ['SQL', 'R', 'SAS', 'Clinical-Trials', 'IDS'],
#  ['R', 'AI', 'SAP', 'Operations-Research', 'Business-Management'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Excel',
#   'Visual-Basic',
#   'Visio',
#   'SharePoint',
#   'Kanban',
#   'VersionOne'],
#  ['R',
#   'Spark',
#   'Tableau',
#   'AWS',
#   'Linux',
#   'Excel',
#   'Docker',
#   'C',
#   '#',
#   'Power-BI',
#   'Apache',
#   'Go'],
#  ['Python', 'SQL', 'R', 'AWS', 'S3', 'Visio'],
#  ['R',
#   'Tableau',
#   'Microsoft-Office',
#   'Excel',
#   'Project-Management',
#   'Business-Intelligence',
#   'Power-BI',
#   'Marketing',
#   'Jira',
#   'Go',
#   'Google-Analytics',
#   'Digital-Marketing',
#   'Accounting',
#   'Adobe-Acrobat'],
#  ['R', 'Excel', 'Network', 'Go'],
#  ['R', 'Excel', 'SaaS'],
#  ['R'],
#  ['SQL', 'R'],
#  ['R'],
#  ['Python',
#   'R',
#   'Java',
#   'AWS',
#   'Azure',
#   'Excel',
#   'Perl',
#   'Ruby',
#   'Google-Cloud-Platform',
#   'Go',
#   'SaaS'],
#  ['R', 'AI'],
#  ['R', 'AI', 'Excel', 'Business-Analysis', 'Change-Management'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Omniture'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Microsoft-Office',
#   'Excel',
#   'Visio',
#   'SharePoint'],
#  ['R', 'AI', 'Project-Management', 'Go'],
#  ['R',
#   'Excel',
#   'Software-Development',
#   'Project-Management',
#   'Business-Analysis',
#   'Visio',
#   'Go',
#   'UI'],
#  ['SQL',
#   'R',
#   'Java',
#   'Oracle',
#   'Excel',
#   'XML',
#   'PL/SQL',
#   'OBIEE',
#   'PeopleSoft',
#   'UX',
#   'Windows'],
#  ['R', 'Excel', 'Marketing', 'Accounting'],
#  ['R', 'Tableau', 'Excel', 'Business-Intelligence', 'Jira'],
#  ['R', 'Visio'],
#  ['SQL',
#   'R',
#   'Oracle',
#   'Microsoft-Office',
#   'Excel',
#   'MySQL',
#   'Windows',
#   'Ellucian'],
#  ['SQL',
#   'R',
#   'Big-Data',
#   'Oracle',
#   'Azure',
#   'Excel',
#   'Teradata',
#   'Data-Management'],
#  ['R', 'Accounting', 'SaaS', 'Payroll'],
#  ['Python', 'SQL', 'R', 'Tableau', 'SAS', 'Teradata'],
#  ['R',
#   'Excel',
#   'Project-Management',
#   'Business-Intelligence',
#   'Time-Management'],
#  ['SQL', 'R', 'AI', 'Business-Analysis', 'UX'],
#  ['R', 'Tableau', 'Excel', 'Alteryx', 'Accounting', 'CPA'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Oracle',
#   'MATLAB',
#   'Microsoft-Office',
#   'Excel',
#   'SPSS',
#   'Data-Science',
#   'Power-BI',
#   'Marketing',
#   'PL/SQL'],
#  ['R',
#   'Microsoft-Office',
#   'Excel',
#   'Business-Intelligence',
#   'Marketing',
#   'SharePoint'],
#  ['SQL', 'R', 'Excel', 'Software-Development', 'SDLC', 'Visio'],
#  ['R', 'SAP'],
#  ['R', 'Excel', 'Accounting', 'Audits'],
#  ['SQL', 'R', 'Excel', 'Splunk', 'SharePoint', 'Information-Security'],
#  ['Python', 'SQL', 'R'],
#  ['Python', 'Machine-Learning', 'R', 'Tableau', 'Excel', 'QlikView', 'CI'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'SAS',
#   'AI',
#   'JavaScript',
#   'Marketing'],
#  ['SQL', 'Excel'],
#  ['SQL', 'R', 'Excel'],
#  ['SQL', 'Tableau', 'Excel', 'Power-BI'],
#  ['R', 'Microsoft-Office', 'Excel', 'Go'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Go'],
#  ['R', 'Microsoft-Office', 'Excel', 'SAP', 'Visio'],
#  ['SQL', 'R'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Oracle',
#   'Excel',
#   'PostgreSQL',
#   'MySQL',
#   'Informatica'],
#  ['R', 'Excel', 'TFS', 'PMP'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Data-Warehouse',
#   'Excel',
#   'Project-Management',
#   'Business-Intelligence',
#   'Business-Analysis',
#   'Network',
#   'Go',
#   'Application-Support',
#   'RN'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Microsoft-SQL-Server',
#   'Microsoft-Office',
#   'Excel',
#   'C',
#   '#',
#   'PowerShell',
#   'Accounting'],
#  ['R', 'Project-Management', 'SharePoint'],
#  ['SQL',
#   'R',
#   'Microsoft-Office',
#   'Excel',
#   'Project-Management',
#   'Visio',
#   'CSS',
#   'RN',
#   'WordPress'],
#  ['Software-Development', '.Net', 'C', '#', 'SharePoint'],
#  ['R', 'Microsoft-Office', 'Excel', 'Business-Intelligence'],
#  ['R'],
#  ['SQL', 'R', 'Microsoft-Office', 'Excel', 'Project-Management', 'Accounting'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Microsoft-Office', 'Excel'],
#  ['SQL',
#   'R',
#   'Hadoop',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Data-Management'],
#  ['SQL', 'R', 'PowerShell', 'Windows'],
#  ['R', 'Excel', 'Visio', 'Hyperion'],
#  ['SQL', 'R', 'Excel', 'JSON', 'XML', 'Go', 'Regulatory-Reporting'],
#  ['SQL', 'R', 'SAS', 'Business-Intelligence'],
#  ['R', 'AI', 'Project-Management', 'Go'],
#  ['SQL',
#   'R',
#   'Tableau',
#   'Data-Analysis',
#   'Excel',
#   'Business-Intelligence',
#   'Power-BI',
#   'Marketing',
#   'Go',
#   'Google-Analytics',
#   'Marketing-Automation',
#   'Salesforce-Marketing-Cloud'],
#  ['SQL', 'Tableau', 'Oracle', 'Ant'],
#  ['Python', 'SQL', 'R', 'Excel'],
#  ['R', 'Excel', 'SPSS', 'Marketing', 'Go'],
#  ['Python', 'SQL', 'R', 'Tableau', 'SAS', 'Excel'],
#  ['SQL',
#   'R',
#   'Excel',
#   'Project-Management',
#   'XML',
#   'Visio',
#   'Go',
#   'Application-Support'],
#  ['R', 'Excel', 'Marketing', 'Visio', 'CI', 'Go', 'Epic', 'Software-Testing'],
#  ['SQL', 'R', 'Oracle', 'Excel', 'UI'],
#  ['Python', 'SQL', 'R', 'AWS', 'S3', 'Visio'],
#  ['R', 'AI', 'SAP', 'Operations-Research', 'Business-Management'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Google-Cloud-Platform',
#   'Go',
#   'Accounting'],
#  ['SQL', 'R', 'Tableau', 'AI', 'Excel', 'SAP', 'Go'],
#  ['Python', 'SQL', 'R', 'Java', 'Tableau', 'SAS', 'Excel'],
#  ['SQL', 'R', 'SAS', 'Microsoft-Office', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'Excel'],
#  ['SQL', 'R', 'SAS', 'Excel', 'Quality-Management', 'Managed-Care'],
#  ['SQL', 'R', 'Excel', 'Visio', 'CI', 'SharePoint'],
#  ['R', 'Microsoft-Office', 'Excel', 'UI'],
#  ['SQL', 'R', 'AI', 'Business-Analysis', 'UX'],
#  ['R', 'AI', 'Excel', 'Accounting', 'IDS'],
#  ['R', 'Marketing', 'Go', 'SEO'],
#  ['R', 'Excel'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Microsoft-Office',
#   'Excel',
#   'Business-Intelligence'],
#  ['R', 'Tableau', 'SAP', 'Go', 'SaaS', 'Social-Media-Management'],
#  ['R', 'AI', 'Excel', 'Business-Analysis', 'Change-Management'],
#  ['R', 'AI', 'UI'],
#  ['R'],
#  ['R', 'Azure', 'Business-Analysis', 'Visio', 'SaaS', 'UI'],
#  ['SQL', 'R', 'Excel'],
#  ['SQL',
#   'R',
#   'Big-Data',
#   'Oracle',
#   'Azure',
#   'Excel',
#   'Teradata',
#   'Data-Management'],
#  ['R', 'Excel', 'Marketing', 'Accounting'],
#  ['R', 'Excel'],
#  ['SQL', 'R', 'Tableau', 'Excel'],
#  ['R'],
#  ['SQL', 'R', 'Tableau', 'AI', 'Business-Intelligence', 'Network'],
#  ['R', 'Excel'],
#  ['SQL', 'R', 'Git', 'Perl', 'Splunk', 'Jenkins', 'Kubernetes', 'SVN', 'Chef'],
#  ['R', 'Excel'],
#  ['SQL', 'R', 'REST', 'Visio', 'Process-Management'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'SAS',
#   'Excel',
#   'Visual-Basic',
#   'Visio',
#   'SharePoint',
#   'Kanban',
#   'VersionOne'],
#  ['R', 'Excel'],
#  ['R', 'Tableau', 'Excel', 'Business-Intelligence', 'Jira'],
#  ['Excel'],
#  ['R', 'SDLC', 'Network', 'Go'],
#  ['SQL', 'R', 'Tableau', 'Excel', 'Power-BI'],
#  ['R', 'CI', 'SharePoint', 'Lean', 'Six-Sigma', 'Business-Management'],
#  ['SQL', 'R', 'Excel', 'UI'],
#  ['R', 'Excel', 'Business-Analysis', 'UX'],
#  ['R', 'Accounting', 'SaaS', 'Payroll'],
#  ['R'],
#  ['R',
#   'Tableau',
#   'Microsoft-Office',
#   'Excel',
#   'Project-Management',
#   'Business-Intelligence',
#   'Power-BI',
#   'Marketing',
#   'Jira',
#   'Go',
#   'Google-Analytics',
#   'Digital-Marketing',
#   'Accounting',
#   'Adobe-Acrobat'],
#  ['Python', 'SQL', 'R', 'Tableau', 'Data-Science', 'Business-Intelligence'],
#  ['R', 'Excel', 'SaaS'],
#  ['SQL', 'R', 'Marketing', 'Performance-Marketing', 'SEO'],
#  ['R', 'Tableau', 'Excel', 'Business-Analysis', 'Accounting'],
#  ['R',
#   'Excel',
#   'Software-Development',
#   'Project-Management',
#   'Business-Analysis',
#   'Visio',
#   'Go',
#   'UI'],
#  ['R',
#   'Software-Development',
#   'SDLC',
#   'Business-Analysis',
#   'Microsoft-Project',
#   'HP-ALM',
#   'VersionOne'],
#  ['R', 'Excel', 'Lean', 'Six-Sigma'],
#  ['R', 'Jira'],
#  ['R', 'Workday'],
#  ['Python',
#   'SQL',
#   'R',
#   'SAS',
#   'NoSQL',
#   'MATLAB',
#   'Data-Science',
#   'Business-Intelligence',
#   'STATA',
#   'Go',
#   'ACH'],
#  ['R',
#   'Spark',
#   'Tableau',
#   'AWS',
#   'Linux',
#   'Excel',
#   'Docker',
#   'C',
#   '#',
#   'Power-BI',
#   'Apache',
#   'Go'],
#  ['SQL', 'R', '.Net', 'C', '#', 'Jira', 'Confluence'],
#  ['R',
#   'Marketing',
#   'Business-Analysis',
#   'Adobe-Marketing',
#   'Change-Management'],
#  ['R'],
#  ['SQL', 'R', 'Excel', 'Microsoft-Access', 'Accounting'],
#  ['R', 'Visio'],
#  ['Python',
#   'SQL',
#   'R',
#   'Tableau',
#   'Excel',
#   'Business-Intelligence',
#   'Omniture'],
#  ['R',
#   'AI',
#   'Microsoft-Office',
#   'Excel',
#   'Project-Management',
#   'CI',
#   'PeopleSoft',
#   'Program-Management'],
#  ['R', 'Oracle', 'Excel', 'Perl', 'CI', 'PeopleSoft'],
#  ['Machine-Learning',
#   'R',
#   'Tableau',
#   'AWS',
#   'Natural-Language-Processing',
#   'AI',
#   'Excel',
#   'Data-Science',
#   'Business-Intelligence',
#   'Accounting'],
#  ['Python',
#   'SQL',
#   'Hadoop',
#   'Spark',
#   'Java',
#   'Tableau',
#   'Big-Data',
#   'Data-Warehouse',
#   'Linux',
#   'Business-Intelligence',
#   'Informatica'],
#  ['Python',
#   'SQL',
#   'R',
#   'Java',
#   'Tableau',
#   'Big-Data',
#   'Data-Warehouse',
#   'Linux',
#   'JavaScript',
#   'Business-Intelligence',
#   'C',
#   '#',
#   'Informatica',
#   'QlikView',
#   'CSS',
#   'Angular',
#   'Node.js'],
#  ['R', 'Microsoft-Office', 'Excel', 'Marketing', 'CI', 'Go', 'Epic'],
#  ['R', 'Excel', 'CPA', 'GAAP'],
#  ['R', 'Perl', 'Jira', 'Selenium', 'LDAP'],
#  ['R', 'Excel', 'SDLC', 'Visio'],
#  ['R', 'Go'],
#  ['SQL', 'R', 'AI', 'Microsoft-Office', 'Excel'],
#  ['R'],
#  ['SQL', 'R', 'Azure', 'Business-Intelligence', 'Power-BI', 'Data-Management']]

# %%
data_ready = tokenized_sents

# %%
import sys
# !{sys.executable} -m spacy download en
import re, numpy as np, pandas as pd
from pprint import pprint

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import lemmatize, simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

# %%
num_topics = 3

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=num_topics, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.203*"SQL" + 0.108*"Tableau" + 0.102*"R" + 0.066*"Python" + 0.061*"Excel" '
#   '+ 0.033*"SAS" + 0.025*"Azure" + 0.025*"Oracle" + 0.021*"Java" + '
#   '0.019*"SaaS"'),
#  (1,
#   '0.258*"R" + 0.179*"Excel" + 0.087*"Go" + 0.067*"Microsoft-Office" + '
#   '0.059*"Visio" + 0.049*"Accounting" + 0.042*"Business-Analysis" + 0.029*"CI" '
#   '+ 0.023*"SharePoint" + 0.015*"Software-Development"'),
#  (2,
#   '0.158*"R" + 0.113*"Business-Intelligence" + 0.085*"AI" + 0.064*"Excel" + '
#   '0.064*"Marketing" + 0.056*"Power-BI" + 0.048*"Project-Management" + '
#   '0.035*"Data-Management" + 0.035*"Jira" + 0.032*"UI"')]

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data_ready):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             0.0              0.6967
# 1            1             2.0              0.4874
# 2            2             1.0              0.7605
# 3            3             1.0              0.5861
# 4            4             1.0              0.6307
# 5            5             1.0              0.6306
# 6            6             0.0              0.9497
# 7            7             1.0              0.7605
# 8            8             1.0              0.8624
# 9            9             1.0              0.6307
#
#                                                                                               Keywords  \
# 0                                       SQL, Tableau, R, Python, Excel, SAS, Azure, Oracle, Java, SaaS
# 1  R, Business-Intelligence, AI, Excel, Marketing, Power-BI, Project-Management, Data-Management, J...
# 2  R, Excel, Go, Microsoft-Office, Visio, Accounting, Business-Analysis, CI, SharePoint, Software-D...
# 3  R, Excel, Go, Microsoft-Office, Visio, Accounting, Business-Analysis, CI, SharePoint, Software-D...
# 4  R, Excel, Go, Microsoft-Office, Visio, Accounting, Business-Analysis, CI, SharePoint, Software-D...
# 5  R, Excel, Go, Microsoft-Office, Visio, Accounting, Business-Analysis, CI, SharePoint, Software-D...
# 6                                       SQL, Tableau, R, Python, Excel, SAS, Azure, Oracle, Java, SaaS
# 7  R, Excel, Go, Microsoft-Office, Visio, Accounting, Business-Analysis, CI, SharePoint, Software-D...
# 8  R, Excel, Go, Microsoft-Office, Visio, Accounting, Business-Analysis, CI, SharePoint, Software-D...
# 9  R, Excel, Go, Microsoft-Office, Visio, Accounting, Business-Analysis, CI, SharePoint, Software-D...
#
#                                                                                             Text
# 0             [Python, SQL, R, Spark, Hive, AWS, Data-Warehouse, Business-Intelligence, Network]
# 1                                                                       [SQL, R, Excel, Network]
# 2                                                                                     [R, Excel]
# 3                                                        [R, Microsoft-Office, Excel, Marketing]
# 4                                                                                            [R]
# 5                                                                                            [R]
# 6  [Python, SQL, R, Java, Tableau, AWS, Data-Analysis, PostgreSQL, MySQL, S3, SaaS, SSH, Tomcat]
# 7                                                                                     [R, Excel]
# 8                                                               [R, Microsoft-Office, Excel, Go]
# 9                                                                                            [R]

# %%
# Display setting to show more characters in column
pd.options.display.max_colwidth = 100

sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf_mallet.head(10)
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.9682
# 1        1.0              0.9145
# 2        2.0              0.8922
#
#                                                                                               Keywords  \
# 0                                       SQL, Tableau, R, Python, Excel, SAS, Azure, Oracle, Java, SaaS
# 1  R, Excel, Go, Microsoft-Office, Visio, Accounting, Business-Analysis, CI, SharePoint, Software-D...
# 2  R, Business-Intelligence, AI, Excel, Marketing, Power-BI, Project-Management, Data-Management, J...
#
#                                                                                    Representative Text
# 0  [Python, SQL, R, Java, Tableau, AWS, Azure, HBase, MongoDB, Ruby, Elasticsearch, REST, Jenkins, ...
# 1                                                      [R, Excel, CI, Go, Telecommunication, IAT, ACH]
# 2                  [R, Excel, Business-Intelligence, Power-BI, Medical-Insurance, Business-Management]

# %%
# 1. Wordcloud of Top N words in each topic
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=STOPWORDS,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=100,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(1, num_topics, figsize=(20,6), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=400)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Job_type ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
from collections import Counter
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(1, num_topics, figsize=(14,6), sharey=True, dpi=80)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.8, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.4, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    ax_twin.set_ylim(0, 0.6); ax.set_ylim(0, 6000)
    ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=10)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'center')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords', fontsize=20, y=1.05)    
plt.show()

# %%
df.to_csv('df_topic.csv')

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
    corpus_sel = corpus[start:end]
    dominant_topics = []
    topic_percentages = []
    for i, corp in enumerate(corpus_sel):
        topic_percs, wordid_topics, wordid_phivalues = model[corp]
        dominant_topic = sorted(topic_percs, key = lambda x: x[1], reverse=True)[0][0]
        dominant_topics.append((i, dominant_topic))
        topic_percentages.append(topic_percs)
    return(dominant_topics, topic_percentages)

dominant_topics, topic_percentages = topics_per_document(model=lda_model, corpus=corpus, end=-1)            

# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])
dominant_topic_in_each_doc = df.groupby('Dominant_Topic').size()
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()

# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in lda_model.show_topics(formatted=False) 
                                 for j, (topic, wt) in enumerate(topics) if j < 4]

df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(', \n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
from matplotlib.ticker import FuncFormatter

# Plot
fig, (ax1) = plt.subplots(1, 1, figsize=(10, 4), dpi=120, sharey=True)

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x, pos: 'Topic ' + str(x)+ '\n' + df_top3words.loc[df_top3words.topic_id==x, 'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Number of Documents by Dominant Topic', fontdict=dict(size=10))
ax1.set_ylabel('Number of Documents')
ax1.set_ylim(0, 1000)

plt.show()

# %%
# Get topic weights and dominant topics ------------
from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook

# Get topic weights
topic_weights = []
for i, row_list in enumerate(lda_model[corpus]):
    topic_weights.append([w for i, w in row_list[0]])

# Array of topic weights    
arr = pd.DataFrame(topic_weights).fillna(0).values

# Keep the well separated points (optional)
arr = arr[np.amax(arr, axis=1) > 0.35]

# Dominant topic number in each doc
topic_num = np.argmax(arr, axis=1)

# tSNE Dimension Reduction
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')
tsne_lda = tsne_model.fit_transform(arr)

# Plot the Topic Clusters using Bokeh
output_notebook()
n_topics = num_topics
mycolors = np.array([color for name, color in mcolors.TABLEAU_COLORS.items()])
plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics), 
              plot_width=1200, plot_height=600)
plot.scatter(x=tsne_lda[:,0], y=tsne_lda[:,1], color=mycolors[topic_num])
show(plot)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 863 samples in 0.000s...
# [t-SNE] Computed neighbors for 863 samples in 0.009s...
# [t-SNE] Computed conditional probabilities for sample 863 / 863
# [t-SNE] Mean sigma: 0.000179
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 48.149300
# [t-SNE] KL divergence after 1000 iterations: 0.200068
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1313">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="4e65ce53-424f-4d42-a3b3-47934570ee27" data-root-id="1314"></div>

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis
# Out:
# /Users/jz/.local/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.270914  0.045017       1        1  43.201660
# 1      0.088254 -0.216288       2        1  33.138741
# 2      0.182659  0.171270       3        1  23.659603, topic_info=    Category        Freq                   Term       Total  loglift  logprob
# 7    Default  399.000000                    SQL  399.000000  30.0000  30.0000
# 1    Default  122.000000  Business-Intelligence  122.000000  29.0000  29.0000
# 19   Default  213.000000                Tableau  213.000000  28.0000  28.0000
# 21   Default  132.000000                     Go  132.000000  27.0000  27.0000
# 46   Default   92.000000                     AI   92.000000  26.0000  26.0000
# 11   Default  101.000000       Microsoft-Office  101.000000  25.0000  25.0000
# 5    Default  129.000000                 Python  129.000000  24.0000  24.0000
# 10   Default   68.000000              Marketing   68.000000  23.0000  23.0000
# 6    Default  757.000000                      R  757.000000  22.0000  22.0000
# 48   Default   89.000000                  Visio   89.000000  21.0000  21.0000
# 89   Default   60.000000               Power-BI   60.000000  20.0000  20.0000
# 38   Default   74.000000             Accounting   74.000000  19.0000  19.0000
# 9    Default  458.000000                  Excel  458.000000  18.0000  18.0000
# 39   Default   52.000000     Project-Management   52.000000  17.0000  17.0000
# 94   Default   63.000000      Business-Analysis   63.000000  16.0000  16.0000
# 58   Default   38.000000        Data-Management   38.000000  15.0000  15.0000
# 70   Default   38.000000                   Jira   38.000000  14.0000  14.0000
# 36   Default   65.000000                    SAS   65.000000  13.0000  13.0000
# 49   Default   34.000000                     UI   34.000000  12.0000  12.0000
# 44   Default   44.000000                     CI   44.000000  11.0000  11.0000
# 69   Default   49.000000                 Oracle   49.000000  10.0000  10.0000
# 96   Default   50.000000                  Azure   50.000000   9.0000   9.0000
# 37   Default   27.000000                   SDLC   27.000000   8.0000   8.0000
# 27   Default   35.000000             SharePoint   35.000000   7.0000   7.0000
# 77   Default   25.000000                    SAP   25.000000   6.0000   6.0000
# 53   Default   23.000000                   Perl   23.000000   5.0000   5.0000
# 13   Default   41.000000                   Java   41.000000   4.0000   4.0000
# 86   Default   20.000000             PeopleSoft   20.000000   3.0000   3.0000
# 18   Default   38.000000                   SaaS   38.000000   2.0000   2.0000
# 24   Default   36.000000                      #   36.000000   1.0000   1.0000
# ..       ...         ...                    ...         ...      ...      ...
# 89    Topic3   59.684944               Power-BI   60.555687   1.4269  -2.8904
# 70    Topic3   37.802090                   Jira   38.532364   1.4223  -3.3471
# 58    Topic3   38.113483        Data-Management   38.925613   1.4203  -3.3389
# 49    Topic3   33.907505                     UI   34.631660   1.4203  -3.4559
# 77    Topic3   25.082680                    SAP   25.776012   1.4141  -3.7573
# 53    Topic3   22.644621                   Perl   23.438639   1.4069  -3.8596
# 4     Topic3   18.640379                Network   19.318520   1.4057  -4.0542
# 37    Topic3   26.450438                   SDLC   27.435799   1.4048  -3.7042
# 86    Topic3   19.880386             PeopleSoft   20.649921   1.4034  -3.9898
# 52    Topic3   13.194498                   Epic   13.914345   1.3883  -4.3997
# 83    Topic3   11.160648    Business-Management   11.886009   1.3784  -4.5671
# 184   Topic3    7.786406               Selenium    8.443063   1.3604  -4.9271
# 183   Topic3    7.786406                   LDAP    8.443063   1.3604  -4.9271
# 65    Topic3    7.739327      Digital-Marketing    8.456064   1.3528  -4.9332
# 47    Topic3    6.240718                    IDS    6.946734   1.3342  -5.1484
# 50    Topic3    5.157116     Quality-Management    5.865846   1.3126  -5.3391
# 59    Topic3    4.938702           Managed-Care    5.636278   1.3093  -5.3824
# 196   Topic3    3.492802        Time-Management    4.173271   1.2634  -5.7288
# 114   Topic3    7.497074             Confluence    9.242418   1.2321  -4.9650
# 172   Topic3    5.748311        Adobe-Marketing    7.288399   1.2040  -5.2306
# 56    Topic3    6.469161    Application-Support    8.278599   1.1948  -5.1125
# 180   Topic3    5.344584      Microsoft-Project    7.167043   1.1480  -5.3034
# 200   Topic3    5.953682          Adobe-Acrobat    8.056420   1.1389  -5.1955
# 186   Topic3    5.786605     Program-Management    8.066862   1.1092  -5.2240
# 129   Topic3    1.815297     Epic-Certification    2.536093   1.1070  -6.3833
# 63    Topic3    1.745433          Biostatistics    2.456897   1.0995  -6.4225
# 187   Topic3    9.229243             VersionOne   14.668841   0.9781  -4.7571
# 201   Topic3    8.120815      Change-Management   12.865997   0.9812  -4.8851
# 6     Topic3  169.239975                      R  757.937134  -0.0579  -1.8482
# 9     Topic3   69.297256                  Excel  458.216553  -0.4475  -2.7411
#
# [130 rows x 6 columns], token_table=      Topic      Freq                     Term
# term
# 24        1  0.995025                        #
# 25        1  0.825679                     .Net
# 25        3  0.150123                     .Net
# 101       1  0.104793                      ACH
# 101       2  0.943136                      ACH
# 46        3  0.988655                       AI
# 0         1  0.992631                      AWS
# 38        2  0.984889               Accounting
# 200       1  0.124125            Adobe-Acrobat
# 200       2  0.248249            Adobe-Acrobat
# 200       3  0.744748            Adobe-Acrobat
# 172       2  0.137204          Adobe-Marketing
# 172       3  0.823226          Adobe-Marketing
# 60        2  0.696758                  Android
# 73        1  0.914487                   Apache
# 56        1  0.120793      Application-Support
# 56        2  0.120793      Application-Support
# 56        3  0.724760      Application-Support
# 55        2  0.958621                   Audits
# 96        1  0.989127                    Azure
# 96        3  0.019783                    Azure
# 64        1  0.992202                 Big-Data
# 63        3  0.814035            Biostatistics
# 94        2  0.989172        Business-Analysis
# 1         1  0.008144    Business-Intelligence
# 1         3  0.993507    Business-Intelligence
# 83        3  0.925458      Business-Management
# 26        1  0.995025                        C
# 44        2  0.988262                       CI
# 106       2  0.954705                      CPA
# ...     ...       ...                      ...
# 136       2  0.857300     Regulatory-Reporting
# 77        3  0.969894                      SAP
# 36        1  0.990112                      SAS
# 37        2  0.036449                     SDLC
# 37        3  0.947667                     SDLC
# 84        2  0.970037                      SEO
# 41        2  0.976021                     SPSS
# 7         1  0.998733                      SQL
# 18        1  0.969848                     SaaS
# 184       3  0.947523                 Selenium
# 27        2  0.977407               SharePoint
# 144       2  0.857906                Six-Sigma
# 144       3  0.085791                Six-Sigma
# 192       1  0.167538  Social-Media-Management
# 192       2  0.670153  Social-Media-Management
# 28        2  0.962788     Software-Development
# 8         1  0.957361                    Spark
# 19        1  0.997597                  Tableau
# 98        1  0.989627                 Teradata
# 196       3  0.718861          Time-Management
# 49        3  0.981761                       UI
# 116       2  0.966164                       UX
# 187       1  0.272687               VersionOne
# 187       2  0.068172               VersionOne
# 187       3  0.613545               VersionOne
# 48        2  0.987278                    Visio
# 141       1  0.942584             Visual-Basic
# 122       2  0.876238                  Windows
# 57        1  0.947241                      XML
# 61        2  0.666048                      iOS
#
# [124 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 3])

# %%
p = pyLDAvis.gensim.prepare(lda_model, corpus, lda_model.id2word)
pyLDAvis.save_html(p, 'lda.html')
# Out:
# /Users/jz/.local/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
