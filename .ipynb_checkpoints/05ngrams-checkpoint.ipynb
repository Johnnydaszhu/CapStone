# %% [markdown]
# https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/

# %%
import pandas as pd
import numpy as np
df_update = pd.read_csv('df_skill_div.csv', index_col=[0])
skill_cell = pd.read_csv('skill_cell.csv',header=None)
skill_rank = pd.read_csv('skills2.csv')

# %%
skill_uni_list = skill_rank['skills'].to_list()

# %%
skill_cell.columns=['skill_list']
skill_cell.head()
# Out:
#                                                                          skill_list
# 0  Python, SQL, R, Spark, Hive, AWS, Data Warehouse, Business Intelligence, Network
# 1                                                            SQL, R, Excel, Network
# 2                                                                          R, Excel
# 3                                             R, Microsoft Office, Excel, Marketing
# 4                                                                                 R

# %%
list_of_skill = skill_cell['skill_list'].to_list()

# %%
import re
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
cleaned_sections = list_of_skill
characters = skill_uni_list[:30]

# %%
sections_dictionary = {}
iterative = 0
for section in cleaned_sections:
    iterative += 1
    for char in characters:
        if char in section:
            if str(iterative) in sections_dictionary.keys():
                sections_dictionary[str(iterative)].append(char)  
            else:
                sections_dictionary[str(iterative)] = [char]

# %%
##set base df (co-occurance matrix)
df = pd.DataFrame(columns = characters, index = characters)
df[:] = int(0)

#iterate through each POV of book and add one for each character-character relationship
#-> in this case, relationship equates to appearing in the same POV
for value in sections_dictionary.values():
    for character1 in characters:
        for character2 in characters:
            if character1 in value and character2 in value:
                df[character1][character2] += 1
                df[character2][character1] += 1

# %%
#df.to_csv('skill_martix.csv')

# %%
#add weights to edges
edge_list = [] #test networkx
for index, row in df.iterrows():
    i = 0
    for col in row:
        weight = float(col)/464
        edge_list.append((index, df.columns[i], weight))
        i += 1

#Remove edge if 0.0
updated_edge_list = [x for x in edge_list if not x[2] == 0.0]

#create duple of char, occurance in novel
node_list = []
for i in characters:
    for e in updated_edge_list:
        if i == e[0] and i == e[1]:
           node_list.append((i, e[2]*6))
for i in node_list:
    if i[1] == 0.0:
        node_list.remove(i)

#remove self references
for i in updated_edge_list:
    if i[0] == i[1]:
        updated_edge_list.remove(i)

# %%
#pd.DataFrame(updated_edge_list,columns=['skills1','skills2','rel']).to_csv('updated_edge_list.csv')

# %%
#set canvas size
plt.subplots(figsize=(20,14))

#networkx graph time!
G = nx.Graph()
for i in sorted(node_list):
    G.add_node(i[0], size = i[1])
G.add_weighted_edges_from(updated_edge_list)

#check data of graphs
#G.nodes(data=True)
#G.edges(data = True)

#manually copy and pasted the node order using 'nx.nodes(G)'
#Couldn't determine another route to listing out the order of nodes for future work
node_order = skill_uni_list

#reorder node list
updated_node_order = []
for i in node_order:
    for x in node_list:
        if x[0] == i:
            updated_node_order.append(x)

node_scalar = 1000
edge_scalar = 20
sizes = [x[1]*node_scalar for x in updated_node_order]
widths = [x*edge_scalar for x in updated_again_edges]

#draw the graph
pos = nx.spring_layout(G, k=0.2, iterations=2)

nx.draw(G, pos, with_labels=True, font_size = 15, font_weight = 'bold', edge_color='grey',
                 node_color='#ADD8E6',alpha=0.6
        ,node_size = sizes, width = widths)

plt.axis('off')
# Out:
# (-0.924190379727444,
#  1.0995446854148834,
#  -1.095968106667849,
#  0.8930423128350164)

# %%
df_skill_pos = pd.DataFrame.from_dict(pos).T

# %%
#df_skill_pos.to_csv('df_skill_pos.csv')

# %%
df
# Out:
#                                  Python  SQL  Machine Learning     R  Hadoop  \
# Python                              420  362                14   380      22
# SQL                                 362  800                12   740      22
# Machine Learning                     14   12                22    22       2
# R                                   380  740                22  1632      24
# Hadoop                               22   22                 2    24      28
# Spark                                22   22                 8    30       6
# Java                                 74   76                 2    92       6
# Tableau                             210  362                 8   448      22
# Data Mining                           0    0                 0     0       0
# Hive                                 12   14                 0    14      10
# SAS                                  80  162                 8   184      10
# Big Data                             12   16                 4    22       6
# AWS                                  38   42                 4    50       2
# Scala                                16   12                 6    14       2
# NoSQL                                 8   10                 0    10       2
# C/C++                                 4    4                 0     2       0
# Natural Language Processing           0    0                 2     2       0
# Oracle                               32   84                 0   104       0
# Data Warehouse                       10   28                 2    26       2
# Linux                                16   16                 0    20       4
# AI                                   32   68                10   114       0
# Microsoft SQL Server                 12   14                 0    14       0
# TensorFlow                            4    2                 2     4       0
# Kafka                                 2    2                 0     2       2
# Data Analysis                         8   16                 4    28       0
# Azure                                10   14                 2    24       2
# MATLAB                                8   10                 6    14       0
# Microsoft Office                     38   84                 0   162       2
# Scripting                             6    4                 0     8       0
# Pig                                   0    0                 0     0       0
# ...                                 ...  ...               ...   ...     ...
# Nursing Experience                    0    0                 0     0       0
# OSPF                                  0    0                 0     0       0
# Omnigraffle                           0    0                 0     0       0
# Pardot                                0    0                 0     2       0
# Payroll                               0    2                 0    12       0
# Pharmacy Residency                    0    0                 0     0       0
# Professional In Human Resources       0    0                 0     0       0
# Program Management                    0    2                 0     4       0
# Project Engineering                   0    0                 0     0       0
# Public Relations                      0    0                 0     2       0
# Public Speaking                       0    0                 0     0       0
# RHCE                                  0    0                 0     0       0
# RHIA                                  0    0                 0     0       0
# RHIT                                  0    0                 0     0       0
# Remote Access Software                0    0                 0     0       0
# Research Laboratory Experience        0    0                 0     0       0
# Responsive Web Design                 0    0                 0     0       0
# SEO                                   6    8                 0    16       0
# SHRM Certified Professional           0    0                 0     0       0
# SSCP                                  0    0                 0     0       0
# Sailpoint                             0    0                 0     0       0
# Software Troubleshooting              0    0                 0     0       0
# Solarwinds                            0    0                 0     0       0
# Struts                                0    0                 0     0       0
# Technical Project Management          0    0                 0     0       0
# TestNG                                0    0                 0     0       0
# UltiPro                               0    0                 0     0       0
# Wireframing                           0    0                 0     0       0
# Xero                                  0    0                 0     0       0
# openSUSE                              0    0                 0     0       0
#
#                                  Spark  Java  Tableau  Data Mining  Hive  ...  \
# Python                              22    74      210            0    12  ...
# SQL                                 22    76      362            0    14  ...
# Machine Learning                     8     2        8            0     0  ...
# R                                   30    92      448            0    14  ...
# Hadoop                               6     6       22            0    10  ...
# Spark                               32     6       10            0     4  ...
# Java                                 6   100       58            0     0  ...
# Tableau                             10    58      476            0     8  ...
# Data Mining                          0     0        0            0     0  ...
# Hive                                 4     0        8            0    14  ...
# SAS                                 10    20       82            0     4  ...
# Big Data                             8    10       10            0     2  ...
# AWS                                 14     8       30            0     2  ...
# Scala                                8     6        4            0     0  ...
# NoSQL                                4     2        6            0     2  ...
# C/C++                                0     2        0            0     0  ...
# Natural Language Processing          0     0        2            0     0  ...
# Oracle                               2    24       50            0     0  ...
# Data Warehouse                       4     6       16            0     2  ...
# Linux                                6     8       16            0     2  ...
# AI                                   0     6       34            0     0  ...
# Microsoft SQL Server                 0     0       10            0     0  ...
# TensorFlow                           2     0        0            0     0  ...
# Kafka                                2     0        2            0     2  ...
# Data Analysis                        0     2        8            0     0  ...
# Azure                                4     8        8            0     0  ...
# MATLAB                               4     0        2            0     0  ...
# Microsoft Office                     4     4       52            0     0  ...
# Scripting                            0     0        4            0     0  ...
# Pig                                  0     0        0            0     0  ...
# ...                                ...   ...      ...          ...   ...  ...
# Nursing Experience                   0     0        0            0     0  ...
# OSPF                                 0     0        0            0     0  ...
# Omnigraffle                          0     0        0            0     0  ...
# Pardot                               0     0        0            0     0  ...
# Payroll                              0     0        2            0     0  ...
# Pharmacy Residency                   0     0        0            0     0  ...
# Professional In Human Resources      0     0        0            0     0  ...
# Program Management                   0     0        2            0     0  ...
# Project Engineering                  0     0        0            0     0  ...
# Public Relations                     0     0        2            0     0  ...
# Public Speaking                      0     0        0            0     0  ...
# RHCE                                 0     0        0            0     0  ...
# RHIA                                 0     0        0            0     0  ...
# RHIT                                 0     0        0            0     0  ...
# Remote Access Software               0     0        0            0     0  ...
# Research Laboratory Experience       0     0        0            0     0  ...
# Responsive Web Design                0     0        0            0     0  ...
# SEO                                  0     2        4            0     0  ...
# SHRM Certified Professional          0     0        0            0     0  ...
# SSCP                                 0     0        0            0     0  ...
# Sailpoint                            0     0        0            0     0  ...
# Software Troubleshooting             0     0        0            0     0  ...
# Solarwinds                           0     0        0            0     0  ...
# Struts                               0     0        0            0     0  ...
# Technical Project Management         0     0        0            0     0  ...
# TestNG                               0     0        0            0     0  ...
# UltiPro                              0     0        0            0     0  ...
# Wireframing                          0     0        0            0     0  ...
# Xero                                 0     0        0            0     0  ...
# openSUSE                             0     0        0            0     0  ...
#
#                                  Sailpoint  Software Troubleshooting  \
# Python                                   0                         0
# SQL                                      0                         0
# Machine Learning                         0                         0
# R                                        0                         0
# Hadoop                                   0                         0
# Spark                                    0                         0
# Java                                     0                         0
# Tableau                                  0                         0
# Data Mining                              0                         0
# Hive                                     0                         0
# SAS                                      0                         0
# Big Data                                 0                         0
# AWS                                      0                         0
# Scala                                    0                         0
# NoSQL                                    0                         0
# C/C++                                    0                         0
# Natural Language Processing              0                         0
# Oracle                                   0                         0
# Data Warehouse                           0                         0
# Linux                                    0                         0
# AI                                       0                         0
# Microsoft SQL Server                     0                         0
# TensorFlow                               0                         0
# Kafka                                    0                         0
# Data Analysis                            0                         0
# Azure                                    0                         0
# MATLAB                                   0                         0
# Microsoft Office                         0                         0
# Scripting                                0                         0
# Pig                                      0                         0
# ...                                    ...                       ...
# Nursing Experience                       0                         0
# OSPF                                     0                         0
